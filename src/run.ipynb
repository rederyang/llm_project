# %%
import random
import json
import os
import time
from schemdraw.parsing import logicparse


def generate_fixed_depth_expression(inputs, depth):
    """
    Generate a boolean expression with exactly the specified depth.
    Avoid consecutive 'not' operations and redundant nesting.
    """
    operators = ["and", "or", "xor"]  # Binary operators
    symbols = [chr(65 + i) for i in range(inputs)]  # A, B, C, D...

    def generate_expr(current_depth, allow_not=True):
        if current_depth == depth:
            # Base case: choose a symbol when depth is reached
            return random.choice(symbols)
        else:
            op = random.choice(operators + (["not"] if allow_not else []))
            if op == "not":
                # Avoid consecutive 'not' by disallowing 'not' in nested call
                if current_depth < depth - 1:
                    exp = f"not {generate_expr(current_depth, allow_not=False)}"
                else:
                    exp = f"not {generate_expr(current_depth + 1, allow_not=False)}"
                return exp
            else:
                # Binary operators increase depth
                left = generate_expr(current_depth + 1)
                right = generate_expr(current_depth + 1)
                # Ensure left and right are distinct
                while left == right:
                    right = generate_expr(current_depth + 1)
                # Add parentheses around left and right if they are not at the deepest layer
                if current_depth + 1 < depth:
                    left = f"({left})"
                    right = f"({right})"
                return f"{left} {op} {right}"

    return generate_expr(0)

def create_circuit_and_metadata(output_dir, num_circuits, inputs, depth):
    """
    Create circuits and save metadata and diagrams as individual JSON and SVG files.
    """
    os.makedirs(output_dir, exist_ok=True)

    for i in range(num_circuits):
        circuit_id = f"circuit_{i + 1}"
        print(f"Generating {circuit_id} ...")
        expression = generate_fixed_depth_expression(inputs, depth)
        # expression = "(not (((C or A) xor (C and C))))"
        print(expression)
        metadata_entry = {
            "circuit_id": circuit_id,
            "expression": expression,
            "inputs": [chr(65 + j) for j in range(inputs)],  # A, B, C, D...
            "depth": depth
        }

        # Save metadata to individual JSON file
        metadata_file = os.path.join(output_dir, f"{circuit_id}.json")
        with open(metadata_file, "w") as f:
            json.dump(metadata_entry, f, indent=4)

        # Create and save the circuit diagram
        try:
            print("Start parsing ...")
            tik = time.time()
            drawing = logicparse(expression, gateH=1.2)
            print(f"Parsing finished in {time.time() - tik} s")
            svg_file = os.path.join(output_dir, f"{circuit_id}.svg")
            drawing.save(svg_file)
        except Exception as e:
            print(f"Error generating circuit diagram for expression {expression}: {e}")

# Parameters
output_directory = "circuits_output"
number_of_circuits = 100  # Number of circuits to generate
number_of_inputs = 3     # Input variables (e.g., A, B, C, D)
fixed_depth = 3          # Fixed depth for all expressions

# Generate circuits and metadata
create_circuit_and_metadata(output_directory, number_of_circuits, number_of_inputs, fixed_depth)
# Out:
# Generating circuit_1 ...
# not ((A and C) or (A xor C)) and ((B or C) or (C xor B))
# Start parsing ...
# Parsing finished in 0.23543596267700195 s
# Generating circuit_2 ...
# ((C and B) xor (B xor A)) or ((not A) or (B and A))
# Start parsing ...
# Parsing finished in 0.16421294212341309 s
# Generating circuit_3 ...
# not ((A xor C) or (C or A)) xor ((B and A) xor (A and C))
# Start parsing ...
# Parsing finished in 0.23108410835266113 s
# Generating circuit_4 ...
# ((A and B) or (C and B)) xor ((not A) or (A and B))
# Start parsing ...
# Parsing finished in 0.1570587158203125 s
# Generating circuit_5 ...
# ((B or C) and (C or B)) or ((C xor A) xor (B and A))
# Start parsing ...
# Parsing finished in 0.15120410919189453 s
# Generating circuit_6 ...
# (not (C and A) xor (A xor C)) xor ((B xor A) xor (C or B))
# Start parsing ...
# Parsing finished in 0.2936398983001709 s
# Generating circuit_7 ...
# (not (not B) xor (C xor B)) xor ((B and C) or (C and B))
# Start parsing ...
# Parsing finished in 0.20365500450134277 s
# Generating circuit_8 ...
# ((C and B) and (B or A)) and ((C xor B) and (A and B))
# Start parsing ...
# Parsing finished in 0.15664005279541016 s
# Generating circuit_9 ...
# ((A xor B) and (C and B)) and ((not A) or (not B))
# Start parsing ...
# Parsing finished in 0.17760491371154785 s
# Generating circuit_10 ...
# (not (C and A) xor (not A)) and ((not A) xor (A xor B))
# Start parsing ...
# Parsing finished in 0.20780515670776367 s
# Generating circuit_11 ...
# ((not C) xor (B xor A)) or ((B and A) or (B or A))
# Start parsing ...
# Parsing finished in 0.16500186920166016 s
# Generating circuit_12 ...
# not ((C or A) and (C and A)) or ((C and B) or (A xor B))
# Start parsing ...
# Parsing finished in 0.2661721706390381 s
# Generating circuit_13 ...
# ((C or A) xor (B or C)) or ((not C) xor (B xor A))
# Start parsing ...
# Parsing finished in 0.16174101829528809 s
# Generating circuit_14 ...
# (not (B or A) and (B or C)) or ((A xor C) or (not B))
# Start parsing ...
# Parsing finished in 0.19697117805480957 s
# Generating circuit_15 ...
# (not (A xor B) and (B and C)) or ((not C) or (not A))
# Start parsing ...
# Parsing finished in 0.20093607902526855 s
# Generating circuit_16 ...
# ((B and A) xor (A or C)) or ((A and C) xor (B and A))
# Start parsing ...
# Parsing finished in 0.15502309799194336 s
# Generating circuit_17 ...
# (not (B xor C) xor (B xor A)) or ((A and B) xor (A xor C))
# Start parsing ...
# Parsing finished in 0.19509410858154297 s
# Generating circuit_18 ...
# ((B xor C) and (C xor A)) xor ((B or A) and (not B))
# Start parsing ...
# Parsing finished in 0.1960587501525879 s
# Generating circuit_19 ...
# ((B and A) and (A xor B)) xor ((A or B) xor (A and C))
# Start parsing ...
# Parsing finished in 0.1571488380432129 s
# Generating circuit_20 ...
# ((not C) and (B or A)) xor ((B xor A) xor (C and B))
# Start parsing ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 86
#      83 fixed_depth = 3          # Fixed depth for all expressions
#      85 # Generate circuits and metadata
# ---> 86 create_circuit_and_metadata(output_directory, number_of_circuits, number_of_inputs, fixed_depth)
#
# Cell In[18], line 72, in create_circuit_and_metadata(output_dir, num_circuits, inputs, depth)
#      70 print("Start parsing ...")
#      71 tik = time.time()
# ---> 72 drawing = logicparse(expression, gateH=1.2)
#      73 print(f"Parsing finished in {time.time() - tik} s")
#      74 svg_file = os.path.join(output_dir, f"{circuit_id}.svg")
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/schemdraw/parsing/logic_parser.py:175, in logicparse(expr, gateW, gateH, outlabel)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/schemdraw/parsing/logic_parser.py:62, in parse_string(logicstr)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/util.py:376, in _inner(self, *args, **kwargs)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:1204, in parse_string(self, instring, parse_all, parseAll)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4152, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (2 times), parseImpl at line 4650 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (2 times), parseImpl at line 5607 (1 times), parseImpl at line 4650 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (5 times), parseImpl at line 5607 (2 times), parseImpl at line 4650 (2 times), parseImpl at line 4381 (2 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4152, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (2 times), parseImpl at line 5607 (1 times), parseImpl at line 4650 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/helpers.py:776, in parseImpl(self, instring, loc, doActions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:920, in try_parse(self, instring, loc, raise_fatal, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/helpers.py:776, in parseImpl(self, instring, loc, doActions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:920, in try_parse(self, instring, loc, raise_fatal, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4152, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4152, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (2 times), parseImpl at line 5607 (1 times), parseImpl at line 4650 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/helpers.py:776, in parseImpl(self, instring, loc, doActions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:920, in try_parse(self, instring, loc, raise_fatal, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4130, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
#     [... skipping similar frames: _parseNoCache at line 850 (1 times)]
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:5607, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4650, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:850, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:4381, in parseImpl(self, instring, loc, do_actions)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:844, in _parseNoCache(self, instring, loc, do_actions, callPreParse)
#
# File ~/miniconda3/envs/598/lib/python3.13/site-packages/pyparsing/core.py:791, in preParse(self, instring, loc)
#
# KeyboardInterrupt:

# %%
import cairosvg

def convert_svg_to_png(svg_path, png_path):
    # Convert SVG to PNG
    cairosvg.svg2png(url=svg_path, write_to=png_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cairosvg
#       3 def convert_svg_to_png(svg_path, png_path):
#       4     # Convert SVG to PNG
#       5     cairosvg.svg2png(url=svg_path, write_to=png_path)
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/cairosvg/__init__.py:26
#      22 VERSION = __version__ = (ROOT / 'VERSION').read_text().strip()
#      25 # VERSION is used in the "url" module imported by "surface"
# ---> 26 from . import surface  # noqa isort:skip
#      29 SURFACES = {
#      30     'PDF': surface.PDFSurface,
#      31     'PNG': surface.PNGSurface,
#    (...)
#      34     'SVG': surface.SVGSurface,
#      35 }
#      38 def svg2svg(bytestring=None, *, file_obj=None, url=None, dpi=96,
#      39             parent_width=None, parent_height=None, scale=1, unsafe=False,
#      40             background_color=None, negate_colors=False, invert_images=False,
#      41             write_to=None, output_width=None, output_height=None):
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/cairosvg/surface.py:9
#       6 import copy
#       7 import io
# ----> 9 import cairocffi as cairo
#      11 from .colors import color, negate_color
#      12 from .defs import (
#      13     apply_filter_after_painting, apply_filter_before_painting, clip_path,
#      14     filter_, gradient_or_pattern, linear_gradient, marker, mask, paint_mask,
#      15     parse_all_defs, pattern, prepare_filter, radial_gradient, use)
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/cairocffi/__init__.py:60
#      55     error_message = '\n'.join(  # pragma: no cover
#      56         str(exception) for exception in exceptions)
#      57     raise OSError(error_message)  # pragma: no cover
# ---> 60 cairo = dlopen(
#      61     ffi, ('cairo-2', 'cairo', 'libcairo-2'),
#      62     ('libcairo.so.2', 'libcairo.2.dylib', 'libcairo-2.dll'))
#      65 class _keepref(object):  # noqa: N801
#      66     """Function wrapper that keeps a reference to another object."""
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/cairocffi/__init__.py:57, in dlopen(ffi, library_names, filenames)
#      53         exceptions.append(exception)
#      55 error_message = '\n'.join(  # pragma: no cover
#      56     str(exception) for exception in exceptions)
# ---> 57 raise OSError(error_message)
#
# OSError: no library called "cairo-2" was found
# no library called "cairo" was found
# no library called "libcairo-2" was found
# cannot load library 'libcairo.so.2': dlopen(libcairo.so.2, 0x0002): tried: 'libcairo.so.2' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibcairo.so.2' (no such file), '/Users/will/miniconda3/envs/598/bin/../lib/libcairo.so.2' (no such file), '/usr/lib/libcairo.so.2' (no such file, not in dyld cache), 'libcairo.so.2' (no such file).  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo.so.2'
# cannot load library 'libcairo.2.dylib': dlopen(libcairo.2.dylib, 0x0002): tried: 'libcairo.2.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibcairo.2.dylib' (no such file), '/Users/will/miniconda3/envs/598/bin/../lib/libcairo.2.dylib' (no such file), '/usr/lib/libcairo.2.dylib' (no such file, not in dyld cache), 'libcairo.2.dylib' (no such file).  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo.2.dylib'
# cannot load library 'libcairo-2.dll': dlopen(libcairo-2.dll, 0x0002): tried: 'libcairo-2.dll' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibcairo-2.dll' (no such file), '/Users/will/miniconda3/envs/598/bin/../lib/libcairo-2.dll' (no such file), '/usr/lib/libcairo-2.dll' (no such file, not in dyld cache), 'libcairo-2.dll' (no such file).  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo-2.dll'

# %%
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM

# read svg -> write png
def convert_svg_to_png(svg_path, png_path):
    # Convert SVG to PNG
    renderPM.drawToFile(svg2rlg(svg_path), png_path, fmt='PNG')

# %%
convert_svg_to_png("/Users/will/libraries/VisualCoT/circuits_output/circuit_1.svg", "test.png")
# cairosvg.svg2png("/Users/will/libraries/VisualCoT/circuits_output/circuit_1.svg", "test.png")
# Out:
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# Unable to find a suitable font for 'font-family:sans', weight:normal, style:normal
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:44, in _getPMBackend(backend)
#      43 try:
# ---> 44     import rlPyCairo as M
#      45 except ImportError as errMsg:
#
# ModuleNotFoundError: No module named 'rlPyCairo'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:47, in _getPMBackend(backend)
#      46 try:
# ---> 47     import _rl_renderPM as M
#      48 except ImportError:
#
# ModuleNotFoundError: No module named '_rl_renderPM'
#
# During handling of the above exception, another exception occurred:
#
# RenderPMError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 convert_svg_to_png("/Users/will/libraries/VisualCoT/circuits_output/circuit_1.svg", "test.png")
#       2 # cairosvg.svg2png("/Users/will/libraries/VisualCoT/circuits_output/circuit_1.svg", "test.png")
#
# Cell In[2], line 7, in convert_svg_to_png(svg_path, png_path)
#       5 def convert_svg_to_png(svg_path, png_path):
#       6     # Convert SVG to PNG
# ----> 7     renderPM.drawToFile(svg2rlg(svg_path), png_path, fmt='PNG')
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:734, in drawToFile(d, fn, fmt, dpi, bg, configPIL, showBoundary, backend, backendFmt)
#     731 def drawToFile(d,fn,fmt='GIF', dpi=72, bg=0xffffff, configPIL=None, showBoundary=rl_config._unset_,backend=rl_config.renderPMBackend,backendFmt='RGB'):
#     732     '''create a pixmap and draw drawing, d to it then save as a file
#     733     configPIL dict is passed to image save method'''
# --> 734     c = drawToPMCanvas(d, dpi=dpi, bg=bg, configPIL=configPIL, showBoundary=showBoundary,backend=backend,backendFmt=backendFmt)
#     735     c.saveToFile(fn,fmt)
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:719, in drawToPMCanvas(d, dpi, bg, configPIL, showBoundary, backend, backendFmt)
#     717 def drawToPMCanvas(d, dpi=72, bg=0xffffff, configPIL=None, showBoundary=rl_config._unset_,backend=rl_config.renderPMBackend,backendFmt='RGB'):
#     718     d = renderScaledDrawing(d)
# --> 719     c = PMCanvas(d.width, d.height, dpi=dpi, bg=bg, configPIL=configPIL, backend=backend,backendFmt=backendFmt)
#     720     draw(d, c, 0, 0, showBoundary=showBoundary)
#     721     return c
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:313, in PMCanvas.__init__(self, w, h, dpi, bg, configPIL, backend, backendFmt)
#     311 w = int(w*scale+0.5)
#     312 h = int(h*scale+0.5)
# --> 313 self.__dict__['_gs'] = self._getGState(w,h,bg,backend,fmt=backendFmt)
#     314 self.__dict__['_bg'] = bg
#     315 self.__dict__['_baseCTM'] = (scale,0,0,scale,0,0)
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:327, in PMCanvas._getGState(w, h, bg, backend, fmt)
#     325 @staticmethod
#     326 def _getGState(w, h, bg, backend=None, fmt='RGB24'):
# --> 327     mod = _getPMBackend(backend)
#     328     if backend is None:
#     329         backend = rl_config.renderPMBackend
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/reportlab/graphics/renderPM.py:49, in _getPMBackend(backend)
#      47                 import _rl_renderPM as M
#      48             except ImportError:
# ---> 49                 raise RenderPMError(f"""cannot import desired renderPM backend {backend}
#      50 Seek advice at the users list see
#      51 https://pairlist2.pair.net/mailman/listinfo/reportlab-users""")
#      52     else:
#      53         raise RenderPMError(f'Invalid renderPM backend, {backend}')
#
# RenderPMError: cannot import desired renderPM backend rlPyCairo
# Seek advice at the users list see
# https://pairlist2.pair.net/mailman/listinfo/reportlab-users

# %%
import cv2
import numpy as np

def detect_components_from_svg(svg_path, output_png_path="circuit_test3.png", output_with_boxes="output_with_components.png"):
    # Step 1: Convert SVG to PNG
    convert_svg_to_png(svg_path, output_png_path)
    
    # Step 2: Load the PNG with OpenCV
    img = cv2.imread(output_png_path)
    original = img.copy()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Preprocessing: Apply GaussianBlur and Canny edge detection
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # List to store detected components
    components = []

    for contour in contours:
        # Get the bounding rectangle for each contour
        x, y, w, h = cv2.boundingRect(contour)
        
        # Filter out noise based on size (min width and height)
        if 80 < h < 120:  # Adjust thresholds as needed
            components.append({'x': x, 'y': y, 'width': w, 'height': h})
            
            # Draw bounding boxes on the original image for visualization
            cv2.rectangle(original, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Save the result with bounding boxes drawn
    cv2.imwrite(output_with_boxes, original)

    return components

# %%
# Input SVG path
svg_path = "circuits_output/circuit_1.svg"

# Detect components
components = detect_components_from_svg(svg_path)

# Print detected components
print("Detected Components:", components)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       2 svg_path = "circuits_output/circuit_1.svg"
#       4 # Detect components
# ----> 5 components = detect_components_from_svg(svg_path)
#       7 # Print detected components
#       8 print("Detected Components:", components)
#
# Cell In[13], line 6, in detect_components_from_svg(svg_path, output_png_path, output_with_boxes)
#       4 def detect_components_from_svg(svg_path, output_png_path="circuit_test3.png", output_with_boxes="output_with_components.png"):
#       5     # Step 1: Convert SVG to PNG
# ----> 6     convert_svg_to_png(svg_path, output_png_path)
#       8     # Step 2: Load the PNG with OpenCV
#       9     img = cv2.imread(output_png_path)
#
# Cell In[12], line 15, in convert_svg_to_png(svg_path, png_path)
#      12 root = tree.getroot()
#      14 # Extract SVG size
# ---> 15 width = int(root.attrib.get("width", 800))  # Default width if not specified
#      16 height = int(root.attrib.get("height", 600))  # Default height if not specified
#      18 # Create a blank image with white background
#
# ValueError: invalid literal for int() with base 10: '238.208pt'

# %%
from sympy import symbols, sympify


# A, B = symbols('A B')

expr_ref = sympify("not (B and A) or (B or A)")
expr_output = sympify("(A or B)")

# %%
print(expr_ref.simplify())
print(expr_output.simplify())
# Out:
# B
# A

# %%
from boolean import BooleanAlgebra

# 初始化布尔代数
algebra = BooleanAlgebra()

# 从字符串解析布尔表达式
expr_output = "not (B and A) or (B or A)"
expr_output = "A ^ B"
expr_ref = "(not (B and A)) and B or A"

expr_output = algebra.parse(expr_output).simplify()
expr_ref = algebra.parse(expr_ref).simplify()

# 化简表达式
print(expr_output)
print(expr_ref)
print(expr_output == expr_ref)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/boolean/boolean.py:537, in BooleanAlgebra.tokenize(self, expr)
#     536 try:
# --> 537     yield TOKENS[tok.lower()], tok, position
#     538 except KeyError:
#
# KeyError: '^'
#
# During handling of the above exception, another exception occurred:
#
# ParseError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 expr_output = "A ^ B"
#       9 expr_ref = "(not (B and A)) and B or A"
# ---> 11 expr_output = algebra.parse(expr_output).simplify()
#      12 expr_ref = algebra.parse(expr_ref).simplify()
#      14 # 化简表达式
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/boolean/boolean.py:224, in BooleanAlgebra.parse(self, expr, simplify)
#     221     return _t in (TOKEN_AND, TOKEN_OR)
#     223 prev_token = None
# --> 224 for token_type, token_string, token_position in tokenized:
#     225     if TRACE_PARSE:
#     226         print(
#     227             "\nprocessing token_type:",
#     228             repr(token_type),
#    (...)
#     232             repr(token_position),
#     233         )
#
# File ~/miniconda3/envs/598/lib/python3.11/site-packages/boolean/boolean.py:542, in BooleanAlgebra.tokenize(self, expr)
#     540         yield TOKEN_SYMBOL, tok, position
#     541     elif tok not in (" ", "\t", "\r", "\n"):
# --> 542         raise ParseError(
#     543             token_string=tok, position=position, error_code=PARSE_UNKNOWN_TOKEN
#     544         )
#     546 position += 1
#
# ParseError: Unknown token for token: "^" at position: 2
