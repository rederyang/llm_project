# %%
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
import cairosvg
import os
import random
import json
import os
import time
from PIL import Image
import cv2
import numpy as np
from schemdraw.parsing import logicparse
def convert_svg_to_png(svg_file, png_file):
    cairosvg.svg2png(url=svg_file, write_to=png_file)

# %%
data_path='./circuits_output/'
for file in os.listdir(data_path):
    if file.endswith('.svg'):
        convert_svg_to_png(data_path+file, data_path+file.replace('.svg', '.png'))

# %%
def load_image(image_path):
    # load the image return the 2D numpy array.
    return np.array(Image.open(image_path))[:, :, 3]

# %%
def get_bbox(img, template_path='./'):
    """
    Generate bounding boxes for logic gates in the given image.
    :param image_path: Path to the PNG image of the circuit.
    :return: List of bounding boxes in the format [(x1, y1, x2, y2, gate_type), ...].
    """

    # Define templates for logic gates and their corresponding colors
    templates = {
        "and": np.array(Image.open(os.path.join(template_path,'and.png')))[:, :, 3],
        "or": np.array(Image.open(os.path.join(template_path,'or.png')))[:, :, 3],
        "not": np.array(Image.open(os.path.join(template_path,'not.png')))[:, :, 3],
        "xor": np.array(Image.open(os.path.join(template_path,'xor.png')))[:, :, 3],
        "notand": np.array(Image.open(os.path.join(template_path,'notand.png')))[:, :, 3],
        "notor": np.array(Image.open(os.path.join(template_path,'notor.png')))[:, :, 3],
        "notxor": np.array(Image.open(os.path.join(template_path,'notxor.png')))[:, :, 3],
    }

    thresholds = {
        "and": 0.90,
        "or": 0.90,
        "not": 0.92,
        "xor": 0.86,
        "notand": 0.84,
        "notor": 0.84,
        "notxor": 0.84,
    }
    bboxes = []

    def calculate_iou(box1, box2):
        # Extract coordinates
        x1, y1, x2, y2 = box1
        x1_p, y1_p, x2_p, y2_p = box2

        # Calculate intersection coordinates
        inter_x1 = max(x1, x1_p)
        inter_y1 = max(y1, y1_p)
        inter_x2 = min(x2, x2_p)
        inter_y2 = min(y2, y2_p)

        # Calculate intersection area
        inter_area = max(0, inter_x2 - inter_x1) * max(0, inter_y2 - inter_y1)

        # Calculate areas of both boxes
        box1_area = (x2 - x1) * (y2 - y1)
        box2_area = (x2_p - x1_p) * (y2_p - y1_p)

        # Calculate union area
        union_area = box1_area + box2_area - inter_area

        # Avoid division by zero
        if union_area == 0:
            return 0

        # IoU
        return inter_area / union_area

    # Perform template matching for each gate
    for gate_type, template in templates.items():
        result = cv2.matchTemplate(img, template, cv2.TM_CCOEFF_NORMED)
        loc = np.where(result >= thresholds[gate_type])
        
        # Generate bounding boxes
        for pt in zip(*loc[::-1]):  # Reverse coordinates
            x1, y1 = pt
            x2, y2 = x1 + template.shape[1], y1 + template.shape[0]
            
            # Apply Non-Maximum Suppression (NMS)
            add_box = True
            for existing_box in bboxes:
                if calculate_iou((x1, y1, x2, y2), existing_box[:4]) > 0.5:  # IoU threshold
                    add_box = False
                    break
            if add_box:
                if int(x1)<50:
                    x1=0
                bboxes.append((int(x1), int(y1), int(x2), int(y2), gate_type))

    return bboxes

# %%
def generate_fixed_depth_expression(inputs, depth):
    """
    Generate a boolean expression with exactly the specified depth.
    Avoid consecutive 'not' operations and redundant nesting.
    """
    operators = ["and", "or", "xor"]  # Binary operators
    symbols = [chr(65 + i) for i in range(inputs)]  # A, B, C, D...

    def generate_expr(current_depth, allow_not=True):
        if current_depth == depth:
            # Base case: choose a symbol when depth is reached
            return random.choice(symbols)
        else:
            op = random.choice(operators + (["not"] if allow_not else []))
            if op == "not":
                # Avoid consecutive 'not' by disallowing 'not' in nested call
                # if current_depth < depth - 1:
                #     exp = f"not {generate_expr(current_depth, allow_not=False)}"
                # else:
                #     exp = f"not {generate_expr(current_depth + 1, allow_not=False)}"
                # return exp
                if current_depth < depth - 1:
                    exp = generate_expr(current_depth, allow_not=False)
                else:
                    exp = generate_expr(current_depth + 1, allow_not=False)
                if exp.startswith('(not') or exp.startswith('not '):
                    return exp
                else:
                    return f'not {exp}'
            else:
                # Binary operators increase depth
                left = generate_expr(current_depth + 1)
                right = generate_expr(current_depth + 1)
                # Ensure left and right are distinct
                while left == right:
                    right = generate_expr(current_depth + 1)
                # Add parentheses around left and right if they are not at the deepest layer
                if current_depth + 1 < depth:
                    left = f"({left})"
                    right = f"({right})"
                return f"{left} {op} {right}"

    return generate_expr(0)

def create_circuit_and_metadata(output_dir, num_circuits, inputs, depth, start_index=1):
    """
    Create circuits and save metadata and diagrams as individual JSON and SVG files.
    """
    os.makedirs(output_dir, exist_ok=True)

    for i in range(num_circuits):
        circuit_id = f"circuit_{i + start_index}"
        print(f"Generating {circuit_id} ...")
        expression = generate_fixed_depth_expression(inputs, depth)
        # expression = "(not (((C or A) xor (C and C))))"
        print(expression)
        

        # Create and save the circuit diagram
        try:
            print("Start parsing ...")
            tik = time.time()
            drawing = logicparse(expression, gateH=1.2)
            
            svg_file = os.path.join(output_dir, f"{circuit_id}.svg")
            drawing.save(svg_file)
            convert_svg_to_png(svg_file, svg_file.replace('.svg', '.png'))
            bbox= get_bbox(load_image(svg_file.replace('.svg', '.png')))
            print(bbox)
            print(f"Parsing finished in {time.time() - tik} s")
            metadata_entry = {
                "circuit_id": circuit_id,
                "expression": expression,
                "inputs": [chr(65 + j) for j in range(inputs)],  # A, B, C, D...
                "depth": depth,
                "bbox": bbox
            }
    
            # Save metadata to individual JSON file
            metadata_file = os.path.join(output_dir, f"{circuit_id}.json")
            with open(metadata_file, "w") as f:
                json.dump(metadata_entry, f, indent=4)
        except Exception as e:
            print(f"Error generating circuit diagram for expression {expression}: {e}")

# %%
# test only
t='((not (not B)) xor (not (not A)))'
name='xor'
drawing = logicparse(t, gateH=1.2)
drawing.save(f'./{name}.svg')
convert_svg_to_png(f'./{name}.svg', f'./{name}.png')

# %%
from PIL import Image

# Load the image
image_path = "./xor.png"
img = Image.open(image_path)

# Define the cropping box (left, upper, right, lower)
# Adjust these values to remove the "B"
crop_box = (0, 0, img.width-15, img.height)  # Example: crop 20 pixels from the left

# Crop the image
cropped_img = img.crop(crop_box)
cropped_img.save(image_path)

# %%
# Parameters
output_directory = "./circuits_output2"
number_of_circuits = 40  # Number of circuits to generate
number_of_inputs = [2,3]     # Input variables (e.g., A, B, C, D)
fixed_depth = [2,3,4]          # Fixed depth for all expressions
start_index = 1
random.seed(0)
for inputs in number_of_inputs:
    for depth in fixed_depth:
        create_circuit_and_metadata(output_directory, number_of_circuits, inputs, depth, start_index)
        start_index += number_of_circuits
# Out:
# Generating circuit_1 ...
# not (B and A) or (B or A)
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (128, 58, 201, 117, 'or'), (0, 116, 105, 175, 'or')]
# Parsing finished in 0.06255602836608887 s
# Generating circuit_2 ...
# (A xor B) and (A and B)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'xor')]
# Parsing finished in 0.045606374740600586 s
# Generating circuit_3 ...
# not (B and A) xor (not B)
# Start parsing ...
# [(0, 86, 105, 146, 'not'), (118, 44, 206, 103, 'xor'), (0, 0, 125, 60, 'notand')]
# Parsing finished in 0.04700040817260742 s
# Generating circuit_4 ...
# (A and B) xor (B and A)
# Start parsing ...
# [(0, 0, 108, 60, 'and'), (0, 115, 108, 175, 'and'), (111, 58, 199, 117, 'xor')]
# Parsing finished in 0.04537153244018555 s
# Generating circuit_5 ...
# (A and B) xor (not A)
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 86, 105, 146, 'not'), (118, 44, 206, 103, 'xor')]
# Parsing finished in 0.050417184829711914 s
# Generating circuit_6 ...
# (A xor B) xor (B or A)
# Start parsing ...
# [(0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.05697989463806152 s
# Generating circuit_7 ...
# not (B or A) or (A or B)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'or')]
# Parsing finished in 0.1632707118988037 s
# Generating circuit_8 ...
# not (A and B) and (A xor B)
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (126, 57, 207, 117, 'and'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04781794548034668 s
# Generating circuit_9 ...
# (not B) xor (A xor B)
# Start parsing ...
# [(0, 0, 105, 60, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor')]
# Parsing finished in 0.04699230194091797 s
# Generating circuit_10 ...
# (not B) and (A or B)
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 87, 110, 146, 'or'), (0, 0, 105, 60, 'not')]
# Parsing finished in 0.04070115089416504 s
# Generating circuit_11 ...
# (B or A) and (B xor A)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 0, 105, 59, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04797720909118652 s
# Generating circuit_12 ...
# (A or B) and (B and A)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'or')]
# Parsing finished in 0.04724431037902832 s
# Generating circuit_13 ...
# (A and B) and (A or B)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (126, 57, 207, 117, 'and'), (0, 116, 105, 175, 'or')]
# Parsing finished in 0.04363894462585449 s
# Generating circuit_14 ...
# (A xor B) and (B xor A)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 0, 105, 59, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.052040815353393555 s
# Generating circuit_15 ...
# (not A) and (B and A)
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 86, 115, 146, 'and'), (0, 0, 105, 60, 'not')]
# Parsing finished in 0.04413127899169922 s
# Generating circuit_16 ...
# (B xor A) xor (A or B)
# Start parsing ...
# [(0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.04793190956115723 s
# Generating circuit_17 ...
# (B and A) xor (A xor B)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.05122256278991699 s
# Generating circuit_18 ...
# (B or A) or (B xor A)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.053733110427856445 s
# Generating circuit_19 ...
# (B or A) and (A or B)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 0, 105, 59, 'or'), (0, 115, 105, 174, 'or')]
# Parsing finished in 0.04300045967102051 s
# Generating circuit_20 ...
# (not A) xor (not B)
# Start parsing ...
# [(0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (118, 29, 206, 88, 'xor')]
# Parsing finished in 0.03972601890563965 s
# Generating circuit_21 ...
# (B or A) and (A xor B)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 0, 105, 59, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04926896095275879 s
# Generating circuit_22 ...
# not (A and B) xor (B xor A)
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.054006099700927734 s
# Generating circuit_23 ...
# not (A and B) and (not B)
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 86, 105, 146, 'not'), (0, 0, 125, 60, 'notand')]
# Parsing finished in 0.04554247856140137 s
# Generating circuit_24 ...
# (A or B) and (A xor B)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 0, 105, 59, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.15760469436645508 s
# Generating circuit_25 ...
# not (A and B) xor (not A)
# Start parsing ...
# [(0, 86, 105, 146, 'not'), (118, 44, 206, 103, 'xor'), (0, 0, 125, 60, 'notand')]
# Parsing finished in 0.05368542671203613 s
# Generating circuit_26 ...
# (B or A) xor (A and B)
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'or'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.0485692024230957 s
# Generating circuit_27 ...
# (A xor B) xor (not B)
# Start parsing ...
# [(0, 86, 105, 146, 'not'), (0, 0, 110, 59, 'xor'), (118, 43, 206, 102, 'xor')]
# Parsing finished in 0.04602766036987305 s
# Generating circuit_28 ...
# (A or B) xor (A xor B)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04719996452331543 s
# Generating circuit_29 ...
# (B xor A) xor (A xor B)
# Start parsing ...
# [(0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04915308952331543 s
# Generating circuit_30 ...
# (B or A) or (A xor B)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04917716979980469 s
# Generating circuit_31 ...
# (B and A) or (not A)
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (133, 44, 206, 103, 'or'), (0, 86, 105, 146, 'not')]
# Parsing finished in 0.04255795478820801 s
# Generating circuit_32 ...
# not (B and A) or (B or A)
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (128, 58, 201, 117, 'or'), (0, 116, 105, 175, 'or')]
# Parsing finished in 0.047170400619506836 s
# Generating circuit_33 ...
# (A and B) and (B xor A)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (126, 57, 207, 117, 'and'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04330801963806152 s
# Generating circuit_34 ...
# not (A xor B) and (B or A)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor')]
# Parsing finished in 0.05067729949951172 s
# Generating circuit_35 ...
# (A and B) xor (A or B)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (0, 116, 105, 175, 'or'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.04669928550720215 s
# Generating circuit_36 ...
# not (A or B) or (not B)
# Start parsing ...
# [(0, 0, 110, 59, 'or'), (133, 43, 206, 102, 'or'), (0, 86, 105, 146, 'not')]
# Parsing finished in 0.04450702667236328 s
# Generating circuit_37 ...
# (B and A) or (not B)
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (133, 44, 206, 103, 'or'), (0, 86, 105, 146, 'not')]
# Parsing finished in 0.04056358337402344 s
# Generating circuit_38 ...
# not (B xor A) xor (A or B)
# Start parsing ...
# [(0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.05100083351135254 s
# Generating circuit_39 ...
# (A xor B) xor (B or A)
# Start parsing ...
# [(0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.05866503715515137 s
# Generating circuit_40 ...
# (A and B) and (B and A)
# Start parsing ...
# [(0, 0, 108, 60, 'and'), (123, 57, 204, 117, 'and'), (0, 115, 108, 175, 'and')]
# Parsing finished in 0.04787302017211914 s
# Generating circuit_41 ...
# ((not A) or (A and B)) or ((B xor A) or (A and B))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (0, 317, 115, 377, 'and'), (133, 44, 206, 103, 'or'), (229, 152, 302, 211, 'or'), (133, 260, 206, 319, 'or'), (0, 0, 105, 60, 'not'), (0, 202, 110, 261, 'xor')]
# Parsing finished in 0.20097875595092773 s
# Generating circuit_42 ...
# ((B and A) xor (A or B)) xor ((A and B) xor (not A))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 230, 115, 290, 'and'), (0, 116, 110, 175, 'or'), (0, 317, 105, 377, 'not'), (118, 58, 206, 117, 'xor'), (214, 166, 302, 225, 'xor'), (118, 274, 206, 333, 'xor')]
# Parsing finished in 0.09847903251647949 s
# Generating circuit_43 ...
# not ((B or A) and (not B)) xor (not (B and A) and (A and B))
# Start parsing ...
# [(130, 230, 211, 290, 'and'), (0, 287, 115, 347, 'and'), (0, 0, 110, 59, 'or'), (0, 86, 105, 146, 'not'), (214, 137, 302, 196, 'xor'), (121, 43, 222, 103, 'notand'), (0, 172, 125, 232, 'notand')]
# Parsing finished in 0.08749890327453613 s
# Generating circuit_44 ...
# ((B or A) xor (B and A)) and ((B or A) xor (A or B))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (221, 172, 302, 232, 'and'), (0, 0, 105, 59, 'or'), (0, 230, 105, 289, 'or'), (0, 346, 105, 405, 'or'), (113, 58, 201, 117, 'xor'), (113, 288, 201, 347, 'xor')]
# Parsing finished in 0.11963176727294922 s
# Generating circuit_45 ...
# not ((not B) or (A and B)) or ((A and B) xor (A xor B))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (0, 202, 115, 262, 'and'), (133, 44, 206, 103, 'or'), (229, 152, 302, 211, 'or'), (0, 0, 105, 60, 'not'), (118, 260, 206, 319, 'xor'), (0, 317, 110, 376, 'xor')]
# Parsing finished in 0.11852121353149414 s
# Generating circuit_46 ...
# not ((not A) and (B and A)) and ((not B) and (not A))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (226, 122, 307, 182, 'and'), (130, 202, 211, 262, 'and'), (0, 0, 105, 60, 'not'), (0, 173, 105, 233, 'not'), (0, 230, 105, 290, 'not'), (120, 43, 221, 103, 'notand')]
# Parsing finished in 0.08836221694946289 s
# Generating circuit_47 ...
# not ((B and A) xor (B xor A)) or ((B or A) and (A or B))
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (125, 288, 206, 348, 'and'), (224, 173, 297, 232, 'or'), (0, 231, 105, 290, 'or'), (0, 346, 105, 405, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.1268324851989746 s
# Generating circuit_48 ...
# ((A or B) and (B and A)) xor ((B or A) and (A and B))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (126, 287, 207, 347, 'and'), (0, 345, 110, 405, 'and'), (0, 0, 105, 59, 'or'), (0, 230, 105, 289, 'or'), (209, 173, 297, 232, 'xor')]
# Parsing finished in 0.09218907356262207 s
# Generating circuit_49 ...
# (not (A or B) and (B xor A)) or ((B and A) or (A and B))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 230, 110, 290, 'and'), (0, 345, 110, 405, 'and'), (0, 0, 105, 59, 'or'), (224, 173, 297, 232, 'or'), (128, 288, 201, 347, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.10161399841308594 s
# Generating circuit_50 ...
# (not (B or A) xor (not B)) xor ((not B) and (not A))
# Start parsing ...
# [(130, 172, 211, 232, 'and'), (0, 0, 110, 59, 'or'), (0, 86, 105, 146, 'not'), (0, 143, 105, 203, 'not'), (0, 201, 105, 261, 'not'), (118, 43, 206, 102, 'xor'), (214, 108, 302, 167, 'xor')]
# Parsing finished in 0.10656285285949707 s
# Generating circuit_51 ...
# ((not A) xor (A or B)) xor ((B or A) and (not B))
# Start parsing ...
# [(130, 245, 211, 305, 'and'), (0, 87, 110, 146, 'or'), (0, 202, 110, 261, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (118, 44, 206, 103, 'xor')]
# Parsing finished in 0.08877706527709961 s
# Generating circuit_52 ...
# ((not B) or (B or A)) or (not (A xor B) and (not A))
# Start parsing ...
# [(130, 245, 211, 305, 'and'), (133, 44, 206, 103, 'or'), (0, 87, 110, 146, 'or'), (229, 144, 302, 203, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (0, 202, 110, 261, 'xor')]
# Parsing finished in 0.18936657905578613 s
# Generating circuit_53 ...
# ((B and A) xor (not B)) or ((not A) and (not B))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (130, 173, 211, 233, 'and'), (229, 108, 302, 167, 'or'), (0, 86, 105, 146, 'not'), (0, 144, 105, 204, 'not'), (0, 201, 105, 261, 'not'), (118, 44, 206, 103, 'xor')]
# Parsing finished in 0.08372235298156738 s
# Generating circuit_54 ...
# ((A xor B) and (not B)) and (not (B xor A) and (A and B))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (226, 136, 307, 196, 'and'), (130, 230, 211, 290, 'and'), (0, 287, 115, 347, 'and'), (0, 86, 105, 146, 'not'), (0, 0, 110, 59, 'xor'), (0, 173, 110, 232, 'xor')]
# Parsing finished in 0.0946652889251709 s
# Generating circuit_55 ...
# ((A and B) xor (B xor A)) xor ((B and A) or (A or B))
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (0, 230, 111, 290, 'and'), (128, 288, 201, 347, 'or'), (0, 346, 105, 405, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor'), (209, 173, 297, 232, 'xor')]
# Parsing finished in 0.10708808898925781 s
# Generating circuit_56 ...
# (not (B xor A) and (not B)) xor ((not A) xor (not B))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 86, 105, 146, 'not'), (0, 143, 105, 203, 'not'), (0, 201, 105, 261, 'not'), (0, 0, 110, 59, 'xor'), (214, 108, 302, 167, 'xor'), (118, 173, 206, 232, 'xor')]
# Parsing finished in 0.0915520191192627 s
# Generating circuit_57 ...
# (not (A or B) and (not B)) or ((A and B) and (B and A))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 172, 115, 232, 'and'), (130, 230, 211, 290, 'and'), (0, 287, 115, 347, 'and'), (0, 0, 110, 59, 'or'), (229, 137, 302, 196, 'or'), (0, 86, 105, 146, 'not')]
# Parsing finished in 0.09373331069946289 s
# Generating circuit_58 ...
# ((B xor A) and (B or A)) and ((not B) and (B xor A))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (226, 151, 307, 211, 'and'), (130, 244, 211, 304, 'and'), (0, 115, 110, 174, 'or'), (0, 201, 105, 261, 'not'), (0, 0, 110, 59, 'xor'), (0, 288, 110, 347, 'xor')]
# Parsing finished in 0.09824752807617188 s
# Generating circuit_59 ...
# ((not A) xor (A xor B)) xor ((not B) xor (A or B))
# Start parsing ...
# [(0, 260, 110, 319, 'or'), (0, 0, 105, 60, 'not'), (0, 173, 105, 233, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor'), (214, 130, 302, 189, 'xor')]
# Parsing finished in 0.09586834907531738 s
# Generating circuit_60 ...
# ((not A) and (A or B)) or ((A or B) and (B and A))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (130, 259, 211, 319, 'and'), (0, 317, 115, 377, 'and'), (0, 87, 110, 146, 'or'), (229, 152, 302, 211, 'or'), (0, 202, 110, 261, 'or'), (0, 0, 105, 60, 'not')]
# Parsing finished in 0.08663773536682129 s
# Generating circuit_61 ...
# (not (B xor A) or (A and B)) xor ((A xor B) and (B or A))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (126, 287, 207, 347, 'and'), (128, 58, 201, 117, 'or'), (0, 346, 105, 405, 'or'), (0, 0, 105, 59, 'xor'), (209, 173, 297, 232, 'xor'), (0, 230, 105, 289, 'xor')]
# Parsing finished in 0.10253214836120605 s
# Generating circuit_62 ...
# not ((A and B) xor (B xor A)) and ((B or A) and (B and A))
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (221, 173, 302, 233, 'and'), (125, 288, 206, 348, 'and'), (0, 345, 111, 405, 'and'), (0, 231, 105, 290, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.20558500289916992 s
# Generating circuit_63 ...
# ((not A) or (not B)) and (not (A and B) or (B or A))
# Start parsing ...
# [(226, 115, 307, 175, 'and'), (133, 29, 206, 88, 'or'), (133, 202, 206, 261, 'or'), (0, 260, 110, 319, 'or'), (0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (0, 144, 125, 204, 'notand')]
# Parsing finished in 0.09713077545166016 s
# Generating circuit_64 ...
# (not (A or B) and (B xor A)) xor ((B or A) xor (A and B))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 345, 110, 405, 'and'), (0, 0, 105, 59, 'or'), (0, 230, 105, 289, 'or'), (0, 115, 105, 174, 'xor'), (209, 173, 297, 232, 'xor'), (113, 288, 201, 347, 'xor')]
# Parsing finished in 0.10458135604858398 s
# Generating circuit_65 ...
# ((A xor B) or (A and B)) or ((B and A) xor (A xor B))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (0, 230, 110, 290, 'and'), (128, 58, 201, 117, 'or'), (224, 173, 297, 232, 'or'), (0, 0, 105, 59, 'xor'), (113, 288, 201, 347, 'xor'), (0, 345, 105, 404, 'xor')]
# Parsing finished in 0.1082756519317627 s
# Generating circuit_66 ...
# ((B xor A) or (A or B)) xor ((A and B) xor (A or B))
# Start parsing ...
# [(0, 230, 110, 290, 'and'), (128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'or'), (0, 346, 105, 405, 'or'), (0, 0, 105, 59, 'xor'), (209, 173, 297, 232, 'xor'), (113, 288, 201, 347, 'xor')]
# Parsing finished in 0.10563516616821289 s
# Generating circuit_67 ...
# ((A or B) or (A xor B)) or ((B and A) and (A or B))
# Start parsing ...
# [(0, 230, 110, 290, 'and'), (126, 287, 207, 347, 'and'), (0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (224, 173, 297, 232, 'or'), (0, 346, 105, 405, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.10191893577575684 s
# Generating circuit_68 ...
# not ((B and A) xor (not A)) xor ((B xor A) xor (A or B))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 288, 110, 347, 'or'), (0, 86, 105, 146, 'not'), (214, 137, 302, 196, 'xor'), (0, 173, 110, 232, 'xor'), (118, 231, 206, 290, 'xor'), (118, 44, 221, 103, 'notxor')]
# Parsing finished in 0.1023104190826416 s
# Generating circuit_69 ...
# ((not A) xor (B xor A)) or ((B and A) xor (B or A))
# Start parsing ...
# [(0, 202, 115, 262, 'and'), (229, 152, 302, 211, 'or'), (0, 317, 110, 376, 'or'), (0, 0, 105, 60, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor'), (118, 260, 206, 319, 'xor')]
# Parsing finished in 0.10498380661010742 s
# Generating circuit_70 ...
# not ((A and B) and (not A)) xor ((not B) or (B or A))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (133, 188, 206, 247, 'or'), (0, 231, 110, 290, 'or'), (0, 86, 105, 146, 'not'), (0, 144, 105, 204, 'not'), (214, 116, 302, 175, 'xor'), (120, 43, 221, 103, 'notand')]
# Parsing finished in 0.08758759498596191 s
# Generating circuit_71 ...
# (not (B and A) or (A and B)) xor ((A or B) or (B and A))
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (0, 115, 110, 175, 'and'), (0, 345, 111, 405, 'and'), (128, 58, 201, 117, 'or'), (0, 231, 105, 290, 'or'), (128, 288, 201, 347, 'or'), (209, 173, 297, 232, 'xor')]
# Parsing finished in 0.2644374370574951 s
# Generating circuit_72 ...
# ((B xor A) xor (B and A)) and ((A xor B) xor (B or A))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (221, 172, 302, 232, 'and'), (0, 346, 105, 405, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor'), (0, 230, 105, 289, 'xor'), (113, 288, 201, 347, 'xor')]
# Parsing finished in 0.10822725296020508 s
# Generating circuit_73 ...
# not ((not B) xor (B and A)) or ((B and A) xor (not B))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (0, 202, 115, 262, 'and'), (229, 144, 302, 203, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (118, 245, 206, 304, 'xor'), (118, 44, 221, 103, 'notxor')]
# Parsing finished in 0.09576034545898438 s
# Generating circuit_74 ...
# not ((A xor B) and (not B)) and ((B and A) or (A xor B))
# Start parsing ...
# [(226, 136, 307, 196, 'and'), (0, 172, 115, 232, 'and'), (133, 230, 206, 289, 'or'), (0, 86, 105, 146, 'not'), (0, 0, 110, 59, 'xor'), (0, 288, 110, 347, 'xor'), (121, 43, 222, 103, 'notand')]
# Parsing finished in 0.10020017623901367 s
# Generating circuit_75 ...
# ((B or A) and (A and B)) and ((A xor B) or (not B))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (0, 115, 115, 175, 'and'), (226, 165, 307, 225, 'and'), (0, 0, 110, 59, 'or'), (133, 274, 206, 333, 'or'), (0, 316, 105, 376, 'not'), (0, 230, 110, 289, 'xor')]
# Parsing finished in 0.09302973747253418 s
# Generating circuit_76 ...
# ((B and A) xor (not A)) xor ((B or A) and (not A))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (130, 216, 211, 276, 'and'), (0, 173, 110, 232, 'or'), (0, 86, 105, 146, 'not'), (0, 259, 105, 319, 'not'), (118, 44, 206, 103, 'xor'), (214, 130, 302, 189, 'xor')]
# Parsing finished in 0.0899507999420166 s
# Generating circuit_77 ...
# ((A or B) xor (not A)) and ((B or A) or (not A))
# Start parsing ...
# [(226, 129, 307, 189, 'and'), (0, 0, 110, 59, 'or'), (0, 173, 110, 232, 'or'), (133, 216, 206, 275, 'or'), (0, 86, 105, 146, 'not'), (0, 259, 105, 319, 'not'), (118, 43, 206, 102, 'xor')]
# Parsing finished in 0.09302139282226562 s
# Generating circuit_78 ...
# (not (A and B) xor (B and A)) and ((B and A) xor (A xor B))
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (0, 115, 110, 175, 'and'), (221, 173, 302, 233, 'and'), (0, 230, 111, 290, 'and'), (113, 58, 201, 117, 'xor'), (0, 346, 105, 405, 'xor')]
# Parsing finished in 0.11102128028869629 s
# Generating circuit_79 ...
# (not (B and A) xor (B xor A)) or (not (A or B) or (A xor B))
# Start parsing ...
# [(0, 0, 111, 60, 'and'), (224, 173, 297, 232, 'or'), (0, 231, 105, 290, 'or'), (128, 288, 201, 347, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor'), (0, 346, 105, 405, 'xor')]
# Parsing finished in 0.11867833137512207 s
# Generating circuit_80 ...
# ((B and A) xor (B xor A)) and ((not B) or (A and B))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (226, 151, 307, 211, 'and'), (0, 288, 115, 348, 'and'), (133, 245, 206, 304, 'or'), (0, 201, 105, 261, 'not'), (118, 58, 206, 117, 'xor'), (0, 115, 110, 174, 'xor')]
# Parsing finished in 0.10011625289916992 s
# Generating circuit_81 ...
# ((not (A xor B) and (B or A)) and (not (A or B) xor (A and B))) and ((not (B or A) xor (not A)) or ((A xor B) and (B xor A)))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (226, 172, 307, 232, 'and'), (0, 345, 115, 405, 'and'), (322, 385, 403, 445, 'and'), (130, 691, 211, 751, 'and'), (0, 115, 110, 174, 'or'), (0, 461, 110, 520, 'or'), (229, 598, 302, 657, 'or'), (0, 547, 105, 607, 'not'), (0, 0, 110, 59, 'xor'), (118, 288, 206, 347, 'xor'), (118, 504, 206, 563, 'xor'), (0, 633, 110, 692, 'xor'), (0, 749, 110, 808, 'xor'), (0, 230, 125, 289, 'notor')]
# Parsing finished in 0.3677198886871338 s
# Generating circuit_82 ...
# (((A or B) and (B and A)) xor ((A xor B) or (B and A))) or ((not (B or A) or (A xor B)) and ((B or A) and (B xor A)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (0, 345, 110, 405, 'and'), (221, 633, 302, 693, 'and'), (125, 748, 206, 808, 'and'), (0, 0, 105, 59, 'or'), (128, 288, 201, 347, 'or'), (320, 403, 393, 462, 'or'), (0, 461, 105, 520, 'or'), (128, 518, 201, 577, 'or'), (0, 691, 105, 750, 'or'), (209, 173, 297, 232, 'xor'), (0, 230, 105, 289, 'xor'), (0, 576, 105, 635, 'xor'), (0, 806, 105, 865, 'xor')]
# Parsing finished in 0.2754850387573242 s
# Generating circuit_83 ...
# (not ((A and B) and (A xor B)) or ((B or A) and (B and A))) and (((A or B) or (B and A)) or ((B or A) or (not A)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (130, 288, 211, 348, 'and'), (0, 346, 115, 406, 'and'), (322, 400, 403, 460, 'and'), (0, 576, 115, 636, 'and'), (229, 173, 302, 232, 'or'), (0, 231, 110, 290, 'or'), (0, 461, 110, 520, 'or'), (133, 519, 206, 578, 'or'), (229, 627, 302, 686, 'or'), (0, 692, 110, 751, 'or'), (133, 735, 206, 794, 'or'), (0, 777, 105, 837, 'not'), (0, 115, 110, 174, 'xor'), (121, 58, 222, 118, 'notand')]
# Parsing finished in 0.23791241645812988 s
# Generating circuit_84 ...
# ((not (A or B) xor (A and B)) and ((not B) and (A xor B))) or ((not (B or A) and (not B)) or ((not B) or (B or A)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (226, 151, 307, 211, 'and'), (130, 244, 211, 304, 'and'), (130, 446, 211, 506, 'and'), (0, 0, 110, 59, 'or'), (325, 335, 398, 394, 'or'), (0, 403, 110, 462, 'or'), (229, 518, 302, 577, 'or'), (133, 590, 206, 649, 'or'), (0, 634, 110, 693, 'or'), (0, 201, 105, 261, 'not'), (0, 489, 105, 549, 'not'), (0, 547, 105, 607, 'not'), (118, 58, 206, 117, 'xor'), (0, 288, 110, 347, 'xor')]
# Parsing finished in 0.2703092098236084 s
# Generating circuit_85 ...
# not (((B xor A) xor (not A)) and ((B and A) xor (A and B))) or (((not B) xor (B and A)) and ((B xor A) or (A xor B)))
# Start parsing ...
# [(0, 172, 115, 232, 'and'), (0, 287, 115, 347, 'and'), (0, 460, 115, 520, 'and'), (226, 525, 307, 585, 'and'), (325, 331, 398, 390, 'or'), (133, 634, 206, 693, 'or'), (0, 86, 105, 146, 'not'), (0, 374, 105, 434, 'not'), (0, 0, 110, 59, 'xor'), (118, 43, 206, 102, 'xor'), (118, 230, 206, 289, 'xor'), (118, 418, 206, 477, 'xor'), (0, 576, 110, 635, 'xor'), (0, 691, 110, 750, 'xor'), (216, 136, 317, 196, 'notand')]
# Parsing finished in 0.3640706539154053 s
# Generating circuit_86 ...
# (((not A) xor (B or A)) or ((B xor A) xor (not B))) xor (not ((A xor B) or (A or B)) xor (not (A and B) or (A or B)))
# Start parsing ...
# [(0, 87, 110, 146, 'or'), (229, 144, 302, 203, 'or'), (0, 490, 110, 549, 'or'), (133, 663, 206, 722, 'or'), (0, 720, 110, 779, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (118, 44, 206, 103, 'xor'), (0, 202, 110, 261, 'xor'), (118, 245, 206, 304, 'xor'), (310, 346, 398, 405, 'xor'), (0, 375, 110, 434, 'xor'), (214, 548, 302, 607, 'xor'), (0, 605, 125, 665, 'notand')]
# Parsing finished in 0.2534618377685547 s
# Generating circuit_87 ...
# (((B and A) xor (B xor A)) xor (not (A xor B) xor (B xor A))) xor (((A and B) or (B or A)) or ((A and B) and (not B)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 461, 115, 521, 'and'), (0, 691, 115, 751, 'and'), (130, 734, 211, 794, 'and'), (133, 519, 206, 578, 'or'), (0, 576, 110, 635, 'or'), (229, 627, 302, 686, 'or'), (0, 777, 105, 837, 'not'), (118, 58, 206, 117, 'xor'), (0, 115, 110, 174, 'xor'), (214, 173, 302, 232, 'xor'), (0, 231, 110, 290, 'xor'), (0, 346, 110, 405, 'xor'), (310, 400, 398, 459, 'xor')]
# Parsing finished in 0.24790525436401367 s
# Generating circuit_88 ...
# (not ((not A) xor (A or B)) or ((not B) or (A xor B))) and ((not (B and A) xor (not B)) or ((not A) or (B xor A)))
# Start parsing ...
# [(322, 310, 403, 370, 'and'), (0, 87, 110, 146, 'or'), (229, 130, 302, 189, 'or'), (133, 216, 206, 275, 'or'), (229, 490, 302, 549, 'or'), (133, 562, 206, 621, 'or'), (0, 0, 105, 60, 'not'), (0, 173, 105, 233, 'not'), (0, 461, 105, 521, 'not'), (0, 518, 105, 578, 'not'), (0, 259, 110, 318, 'xor'), (118, 418, 206, 477, 'xor'), (0, 605, 110, 664, 'xor'), (0, 374, 125, 434, 'notand'), (118, 44, 221, 103, 'notxor')]
# Parsing finished in 0.2426469326019287 s
# Generating circuit_89 ...
# (((A xor B) or (A and B)) xor ((not A) xor (B xor A))) or (((B or A) xor (A or B)) and (not (B and A) xor (A and B)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (226, 575, 307, 635, 'and'), (0, 748, 115, 808, 'and'), (133, 58, 206, 117, 'or'), (325, 364, 398, 423, 'or'), (0, 403, 110, 462, 'or'), (0, 518, 110, 577, 'or'), (0, 201, 105, 261, 'not'), (0, 0, 110, 59, 'xor'), (214, 151, 302, 210, 'xor'), (118, 245, 206, 304, 'xor'), (0, 288, 110, 347, 'xor'), (118, 461, 206, 520, 'xor'), (118, 691, 206, 750, 'xor'), (0, 633, 125, 693, 'notand')]
# Parsing finished in 0.37458348274230957 s
# Generating circuit_90 ...
# (((B and A) or (B xor A)) xor ((A xor B) or (B xor A))) xor (((not A) or (B xor A)) and (not (B and A) or (A xor B)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (226, 583, 307, 643, 'and'), (133, 58, 206, 117, 'or'), (133, 288, 206, 347, 'or'), (133, 476, 206, 535, 'or'), (133, 692, 206, 751, 'or'), (0, 432, 105, 492, 'not'), (0, 115, 110, 174, 'xor'), (214, 173, 302, 232, 'xor'), (0, 231, 110, 290, 'xor'), (0, 346, 110, 405, 'xor'), (0, 519, 110, 578, 'xor'), (0, 749, 110, 808, 'xor'), (0, 634, 125, 694, 'notand')]
# Parsing finished in 0.24863767623901367 s
# Generating circuit_91 ...
# not (((not B) or (B or A)) and ((A and B) xor (B xor A))) and (not ((not A) and (A xor B)) and ((A and B) or (A or B)))
# Start parsing ...
# [(0, 202, 115, 262, 'and'), (322, 353, 403, 413, 'and'), (226, 554, 307, 614, 'and'), (0, 605, 115, 665, 'and'), (133, 44, 206, 103, 'or'), (0, 87, 110, 146, 'or'), (133, 663, 206, 722, 'or'), (0, 720, 110, 779, 'or'), (0, 0, 105, 60, 'not'), (0, 403, 105, 463, 'not'), (118, 260, 206, 319, 'xor'), (0, 317, 110, 376, 'xor'), (0, 490, 110, 549, 'xor'), (216, 151, 317, 211, 'notand'), (121, 446, 222, 506, 'notand')]
# Parsing finished in 0.253765344619751 s
# Generating circuit_92 ...
# (((B or A) or (not A)) or (not (A xor B) and (B xor A))) and (((A and B) xor (B or A)) and (not (A and B) xor (B and A)))
# Start parsing ...
# [(130, 230, 211, 290, 'and'), (322, 356, 403, 416, 'and'), (0, 403, 115, 463, 'and'), (226, 575, 307, 635, 'and'), (0, 748, 115, 808, 'and'), (0, 0, 110, 59, 'or'), (133, 43, 206, 102, 'or'), (229, 137, 302, 196, 'or'), (0, 518, 110, 577, 'or'), (0, 86, 105, 146, 'not'), (0, 173, 110, 232, 'xor'), (0, 288, 110, 347, 'xor'), (118, 461, 206, 520, 'xor'), (118, 691, 206, 750, 'xor'), (0, 633, 125, 693, 'notand')]
# Parsing finished in 0.2770988941192627 s
# Generating circuit_93 ...
# not (((not B) or (not A)) xor ((B or A) xor (B xor A))) xor (not ((not B) and (B or A)) xor ((not B) xor (A or B)))
# Start parsing ...
# [(133, 29, 206, 88, 'or'), (0, 144, 110, 203, 'or'), (0, 432, 110, 491, 'or'), (0, 605, 110, 664, 'or'), (0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (0, 345, 105, 405, 'not'), (0, 518, 105, 578, 'not'), (118, 202, 206, 261, 'xor'), (0, 259, 110, 318, 'xor'), (310, 296, 398, 355, 'xor'), (214, 476, 302, 535, 'xor'), (118, 562, 206, 621, 'xor'), (120, 389, 221, 449, 'notand'), (214, 116, 317, 175, 'notxor')]
# Parsing finished in 0.31602025032043457 s
# Generating circuit_94 ...
# ((not (A or B) xor (A and B)) xor ((A xor B) and (not A))) xor (not ((B or A) or (A xor B)) or ((not A) or (B or A)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (130, 273, 211, 333, 'and'), (0, 0, 110, 59, 'or'), (0, 403, 110, 462, 'or'), (133, 461, 206, 520, 'or'), (229, 554, 302, 613, 'or'), (133, 648, 206, 707, 'or'), (0, 691, 110, 750, 'or'), (0, 316, 105, 376, 'not'), (0, 604, 105, 664, 'not'), (118, 58, 206, 117, 'xor'), (214, 166, 302, 225, 'xor'), (0, 230, 110, 289, 'xor'), (310, 360, 398, 419, 'xor'), (0, 518, 110, 577, 'xor')]
# Parsing finished in 0.23572015762329102 s
# Generating circuit_95 ...
# (((A or B) and (B xor A)) and ((B xor A) or (A or B))) and (not ((A xor B) or (A or B)) xor (not (A or B) xor (B xor A)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (221, 172, 302, 232, 'and'), (317, 403, 398, 463, 'and'), (0, 0, 105, 59, 'or'), (128, 288, 201, 347, 'or'), (0, 346, 105, 405, 'or'), (0, 576, 105, 635, 'or'), (0, 691, 105, 750, 'or'), (0, 115, 105, 174, 'xor'), (0, 230, 105, 289, 'xor'), (0, 461, 105, 520, 'xor'), (209, 634, 297, 693, 'xor'), (113, 749, 201, 808, 'xor'), (0, 806, 105, 865, 'xor')]
# Parsing finished in 0.2900230884552002 s
# Generating circuit_96 ...
# (not ((not B) or (A xor B)) and ((not B) or (B and A))) and (not ((B or A) xor (A and B)) or ((not B) and (B xor A)))
# Start parsing ...
# [(226, 130, 307, 190, 'and'), (0, 259, 115, 319, 'and'), (322, 328, 403, 388, 'and'), (0, 490, 115, 550, 'and'), (130, 619, 211, 679, 'and'), (133, 44, 206, 103, 'or'), (133, 216, 206, 275, 'or'), (0, 375, 110, 434, 'or'), (229, 526, 302, 585, 'or'), (0, 0, 105, 60, 'not'), (0, 173, 105, 233, 'not'), (0, 576, 105, 636, 'not'), (0, 87, 110, 146, 'xor'), (0, 663, 110, 722, 'xor')]
# Parsing finished in 0.25211310386657715 s
# Generating circuit_97 ...
# (not ((A or B) or (B xor A)) xor ((B xor A) xor (B and A))) and ((not (B xor A) and (A xor B)) or ((A xor B) and (A and B)))
# Start parsing ...
# [(0, 345, 110, 405, 'and'), (317, 403, 398, 463, 'and'), (125, 518, 206, 578, 'and'), (125, 748, 206, 808, 'and'), (0, 806, 110, 866, 'and'), (0, 0, 105, 59, 'or'), (224, 634, 297, 693, 'or'), (0, 115, 105, 174, 'xor'), (209, 173, 297, 232, 'xor'), (0, 230, 105, 289, 'xor'), (113, 288, 201, 347, 'xor'), (0, 461, 105, 520, 'xor'), (0, 576, 105, 635, 'xor'), (0, 691, 105, 750, 'xor')]
# Parsing finished in 0.38606715202331543 s
# Generating circuit_98 ...
# (((B or A) or (not B)) or ((B xor A) or (B or A))) and (((B and A) and (A and B)) xor ((B or A) and (B xor A)))
# Start parsing ...
# [(322, 356, 403, 416, 'and'), (0, 403, 115, 463, 'and'), (130, 460, 211, 520, 'and'), (0, 518, 115, 578, 'and'), (130, 691, 211, 751, 'and'), (0, 0, 110, 59, 'or'), (133, 43, 206, 102, 'or'), (229, 137, 302, 196, 'or'), (133, 230, 206, 289, 'or'), (0, 288, 110, 347, 'or'), (0, 634, 110, 693, 'or'), (0, 86, 105, 146, 'not'), (0, 173, 110, 232, 'xor'), (214, 576, 302, 635, 'xor'), (0, 749, 110, 808, 'xor')]
# Parsing finished in 0.24831414222717285 s
# Generating circuit_99 ...
# (not ((not B) and (B or A)) and (not (A xor B) xor (B and A))) xor (((A xor B) or (not B)) or ((B xor A) or (not B)))
# Start parsing ...
# [(226, 151, 307, 211, 'and'), (0, 317, 115, 377, 'and'), (0, 87, 110, 146, 'or'), (133, 476, 206, 535, 'or'), (229, 562, 302, 621, 'or'), (133, 648, 206, 707, 'or'), (0, 0, 105, 60, 'not'), (0, 518, 105, 578, 'not'), (0, 691, 105, 751, 'not'), (0, 202, 110, 261, 'xor'), (118, 260, 206, 319, 'xor'), (310, 357, 398, 416, 'xor'), (0, 432, 110, 491, 'xor'), (0, 605, 110, 664, 'xor'), (120, 43, 221, 103, 'notand')]
# Parsing finished in 0.21472787857055664 s
# Generating circuit_100 ...
# (((not B) or (A and B)) and ((A or B) and (B and A))) or ((not (B xor A) or (B or A)) or ((A or B) or (A and B)))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (226, 151, 307, 211, 'and'), (130, 259, 211, 319, 'and'), (0, 317, 115, 377, 'and'), (0, 778, 115, 838, 'and'), (133, 44, 206, 103, 'or'), (0, 202, 110, 261, 'or'), (325, 378, 398, 437, 'or'), (133, 490, 206, 549, 'or'), (0, 548, 110, 607, 'or'), (229, 605, 302, 664, 'or'), (0, 663, 110, 722, 'or'), (133, 720, 206, 779, 'or'), (0, 0, 105, 60, 'not'), (0, 432, 110, 491, 'xor')]
# Parsing finished in 0.24822688102722168 s
# Generating circuit_101 ...
# (((A or B) or (B and A)) or ((not A) and (not B))) or (((not A) xor (A or B)) or (not (B xor A) xor (A or B)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (130, 230, 211, 290, 'and'), (0, 0, 110, 59, 'or'), (133, 58, 206, 117, 'or'), (229, 144, 302, 203, 'or'), (325, 306, 398, 365, 'or'), (0, 403, 110, 462, 'or'), (229, 468, 302, 527, 'or'), (0, 634, 110, 693, 'or'), (0, 201, 105, 261, 'not'), (0, 259, 105, 319, 'not'), (0, 316, 105, 376, 'not'), (118, 360, 206, 419, 'xor'), (0, 518, 110, 577, 'xor'), (118, 576, 206, 635, 'xor')]
# Parsing finished in 0.3447597026824951 s
# Generating circuit_102 ...
# (not ((A xor B) or (B xor A)) xor ((not A) and (not B))) or (not ((not B) and (B xor A)) or ((not A) or (A xor B)))
# Start parsing ...
# [(130, 230, 211, 290, 'and'), (325, 295, 398, 354, 'or'), (229, 446, 302, 505, 'or'), (133, 533, 206, 592, 'or'), (0, 201, 105, 261, 'not'), (0, 259, 105, 319, 'not'), (0, 316, 105, 376, 'not'), (0, 489, 105, 549, 'not'), (0, 0, 110, 59, 'xor'), (0, 115, 110, 174, 'xor'), (214, 144, 302, 203, 'xor'), (0, 403, 110, 462, 'xor'), (0, 576, 110, 635, 'xor'), (121, 359, 222, 419, 'notand')]
# Parsing finished in 0.25160717964172363 s
# Generating circuit_103 ...
# (((not A) or (B or A)) xor ((A or B) and (A and B))) xor (((A and B) and (B or A)) xor (not (A and B) and (A xor B)))
# Start parsing ...
# [(130, 259, 211, 319, 'and'), (0, 317, 115, 377, 'and'), (0, 432, 115, 492, 'and'), (130, 490, 211, 550, 'and'), (130, 720, 211, 780, 'and'), (133, 44, 206, 103, 'or'), (0, 87, 110, 146, 'or'), (0, 202, 110, 261, 'or'), (0, 548, 110, 607, 'or'), (0, 0, 105, 60, 'not'), (214, 152, 302, 211, 'xor'), (214, 605, 302, 664, 'xor'), (0, 778, 110, 837, 'xor'), (0, 662, 125, 722, 'notand')]
# Parsing finished in 0.21735382080078125 s
# Generating circuit_104 ...
# (((B or A) or (not A)) xor ((B and A) and (A or B))) or (((A or B) xor (B or A)) xor (not (B and A) and (not A)))
# Start parsing ...
# [(0, 172, 115, 232, 'and'), (130, 230, 211, 290, 'and'), (130, 676, 211, 736, 'and'), (0, 0, 110, 59, 'or'), (133, 43, 206, 102, 'or'), (0, 288, 110, 347, 'or'), (325, 353, 398, 412, 'or'), (0, 403, 110, 462, 'or'), (0, 518, 110, 577, 'or'), (0, 86, 105, 146, 'not'), (0, 719, 105, 779, 'not'), (214, 137, 302, 196, 'xor'), (118, 461, 206, 520, 'xor'), (214, 569, 302, 628, 'xor'), (0, 633, 125, 693, 'notand')]
# Parsing finished in 0.24140238761901855 s
# Generating circuit_105 ...
# (((not B) or (B and A)) and ((A and B) xor (not B))) and (((A or B) xor (A and B)) and ((B xor A) or (not A)))
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (226, 144, 307, 204, 'and'), (0, 202, 115, 262, 'and'), (322, 342, 403, 402, 'and'), (0, 490, 115, 550, 'and'), (226, 540, 307, 600, 'and'), (133, 44, 206, 103, 'or'), (0, 375, 110, 434, 'or'), (133, 648, 206, 707, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (0, 691, 105, 751, 'not'), (118, 245, 206, 304, 'xor'), (0, 605, 110, 664, 'xor')]
# Parsing finished in 0.2279508113861084 s
# Generating circuit_106 ...
# (((B and A) or (not A)) or ((A and B) and (A or B))) or (((B or A) xor (B and A)) and ((not B) xor (A and B)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 173, 115, 233, 'and'), (130, 230, 211, 290, 'and'), (0, 518, 115, 578, 'and'), (226, 554, 307, 614, 'and'), (0, 691, 115, 751, 'and'), (133, 44, 206, 103, 'or'), (229, 137, 302, 196, 'or'), (0, 288, 110, 347, 'or'), (325, 346, 398, 405, 'or'), (0, 404, 110, 463, 'or'), (0, 86, 105, 146, 'not'), (0, 605, 105, 665, 'not'), (118, 461, 206, 520, 'xor')]
# Parsing finished in 0.35437798500061035 s
# Generating circuit_107 ...
# (not ((not A) xor (A or B)) xor ((A or B) xor (A and B))) or (((not B) xor (B xor A)) xor ((not B) and (A xor B)))
# Start parsing ...
# [(0, 317, 115, 377, 'and'), (130, 619, 211, 679, 'and'), (0, 87, 110, 146, 'or'), (0, 202, 110, 261, 'or'), (325, 342, 398, 401, 'or'), (0, 0, 105, 60, 'not'), (0, 403, 105, 463, 'not'), (0, 576, 105, 636, 'not'), (214, 152, 302, 211, 'xor'), (118, 260, 206, 319, 'xor'), (118, 447, 206, 506, 'xor'), (0, 490, 110, 549, 'xor'), (214, 533, 302, 592, 'xor'), (0, 663, 110, 722, 'xor'), (118, 44, 221, 103, 'notxor')]
# Parsing finished in 0.27990221977233887 s
# Generating circuit_108 ...
# ((not (A or B) xor (B and A)) xor ((B xor A) xor (B or A))) and ((not (B or A) xor (B and A)) and (not (B xor A) or (not B)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (322, 399, 403, 459, 'and'), (0, 575, 115, 635, 'and'), (226, 626, 307, 686, 'and'), (0, 0, 110, 59, 'or'), (0, 346, 110, 405, 'or'), (0, 461, 110, 520, 'or'), (133, 734, 206, 793, 'or'), (0, 777, 105, 837, 'not'), (118, 58, 206, 117, 'xor'), (214, 173, 302, 232, 'xor'), (0, 230, 110, 289, 'xor'), (118, 288, 206, 347, 'xor'), (118, 518, 206, 577, 'xor'), (0, 691, 110, 750, 'xor')]
# Parsing finished in 0.276749849319458 s
# Generating circuit_109 ...
# ((not (A or B) or (B or A)) xor ((B or A) xor (B and A))) or (((A or B) xor (B or A)) or ((not B) xor (A and B)))
# Start parsing ...
# [(0, 345, 115, 405, 'and'), (0, 748, 115, 808, 'and'), (0, 0, 110, 59, 'or'), (133, 58, 206, 117, 'or'), (0, 115, 110, 174, 'or'), (0, 230, 110, 289, 'or'), (325, 392, 398, 451, 'or'), (0, 461, 110, 520, 'or'), (0, 576, 110, 635, 'or'), (229, 612, 302, 671, 'or'), (0, 662, 105, 722, 'not'), (214, 173, 302, 232, 'xor'), (118, 288, 206, 347, 'xor'), (118, 518, 206, 577, 'xor'), (118, 706, 206, 765, 'xor')]
# Parsing finished in 0.42968273162841797 s
# Generating circuit_110 ...
# (((not B) xor (B xor A)) xor ((B and A) and (B xor A))) and (((A and B) and (B and A)) and ((B xor A) or (A or B)))
# Start parsing ...
# [(0, 202, 115, 262, 'and'), (130, 259, 211, 319, 'and'), (322, 378, 403, 438, 'and'), (0, 432, 115, 492, 'and'), (130, 490, 211, 550, 'and'), (0, 547, 115, 607, 'and'), (226, 605, 307, 665, 'and'), (133, 720, 206, 779, 'or'), (0, 778, 110, 837, 'or'), (0, 0, 105, 60, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor'), (214, 152, 302, 211, 'xor'), (0, 317, 110, 376, 'xor'), (0, 663, 110, 722, 'xor')]
# Parsing finished in 0.25145912170410156 s
# Generating circuit_111 ...
# not (((A or B) xor (not A)) or ((B and A) xor (A and B))) or (((not A) or (A xor B)) or ((not A) xor (A xor B)))
# Start parsing ...
# [(0, 172, 115, 232, 'and'), (0, 287, 115, 347, 'and'), (0, 0, 110, 59, 'or'), (229, 137, 302, 196, 'or'), (325, 320, 398, 379, 'or'), (133, 418, 206, 477, 'or'), (229, 504, 302, 563, 'or'), (0, 86, 105, 146, 'not'), (0, 374, 105, 434, 'not'), (0, 547, 105, 607, 'not'), (118, 43, 206, 102, 'xor'), (118, 230, 206, 289, 'xor'), (0, 461, 110, 520, 'xor'), (118, 590, 206, 649, 'xor'), (0, 633, 110, 692, 'xor')]
# Parsing finished in 0.2521507740020752 s
# Generating circuit_112 ...
# not (((B or A) xor (A and B)) xor ((not B) or (A or B))) or ((not (B and A) xor (A or B)) or ((not A) xor (B and A)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (0, 691, 115, 751, 'and'), (0, 0, 110, 59, 'or'), (133, 245, 206, 304, 'or'), (0, 288, 110, 347, 'or'), (325, 353, 398, 412, 'or'), (0, 518, 110, 577, 'or'), (229, 554, 302, 613, 'or'), (0, 201, 105, 261, 'not'), (0, 604, 105, 664, 'not'), (118, 58, 206, 117, 'xor'), (214, 151, 302, 210, 'xor'), (118, 461, 206, 520, 'xor'), (118, 648, 206, 707, 'xor'), (0, 403, 125, 463, 'notand')]
# Parsing finished in 0.28102898597717285 s
# Generating circuit_113 ...
# not (((A or B) and (not A)) or ((A or B) or (A and B))) xor (not ((not A) xor (B xor A)) xor ((B or A) and (A or B)))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 287, 115, 347, 'and'), (130, 633, 211, 693, 'and'), (0, 0, 110, 59, 'or'), (229, 137, 302, 196, 'or'), (0, 173, 110, 232, 'or'), (133, 230, 206, 289, 'or'), (0, 576, 110, 635, 'or'), (0, 691, 110, 750, 'or'), (0, 86, 105, 146, 'not'), (0, 374, 105, 434, 'not'), (310, 331, 398, 390, 'xor'), (0, 461, 110, 520, 'xor'), (214, 526, 302, 585, 'xor'), (118, 418, 221, 477, 'notxor')]
# Parsing finished in 0.36600184440612793 s
# Generating circuit_114 ...
# not (((not B) xor (A xor B)) xor ((A and B) xor (A or B))) and (((A xor B) or (A or B)) xor ((not B) xor (A and B)))
# Start parsing ...
# [(0, 202, 115, 262, 'and'), (322, 367, 403, 427, 'and'), (0, 720, 115, 780, 'and'), (0, 317, 110, 376, 'or'), (133, 490, 206, 549, 'or'), (0, 548, 110, 607, 'or'), (0, 0, 105, 60, 'not'), (0, 633, 105, 693, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor'), (118, 260, 206, 319, 'xor'), (0, 432, 110, 491, 'xor'), (214, 584, 302, 643, 'xor'), (118, 677, 206, 736, 'xor'), (214, 152, 317, 211, 'notxor')]
# Parsing finished in 0.2744455337524414 s
# Generating circuit_115 ...
# (((B or A) or (A and B)) xor (not (B and A) and (A xor B))) and (((A and B) and (B xor A)) or ((A and B) or (A or B)))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (0, 230, 111, 290, 'and'), (126, 287, 207, 347, 'and'), (317, 403, 398, 463, 'and'), (0, 460, 110, 520, 'and'), (125, 518, 206, 578, 'and'), (0, 691, 110, 751, 'and'), (0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (224, 634, 297, 693, 'or'), (128, 749, 201, 808, 'or'), (0, 806, 105, 865, 'or'), (209, 173, 297, 232, 'xor'), (0, 345, 105, 404, 'xor'), (0, 576, 105, 635, 'xor')]
# Parsing finished in 0.28157687187194824 s
# Generating circuit_116 ...
# ((not (B xor A) xor (A and B)) xor ((B xor A) and (A xor B))) and (((B xor A) and (A xor B)) xor ((B or A) xor (A xor B)))
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (126, 287, 207, 347, 'and'), (317, 403, 398, 463, 'and'), (125, 518, 206, 578, 'and'), (0, 691, 105, 750, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor'), (209, 173, 297, 232, 'xor'), (0, 230, 105, 289, 'xor'), (0, 345, 105, 404, 'xor'), (0, 461, 105, 520, 'xor'), (0, 576, 105, 635, 'xor'), (209, 634, 297, 693, 'xor'), (113, 749, 201, 808, 'xor'), (0, 806, 105, 865, 'xor')]
# Parsing finished in 0.3452746868133545 s
# Generating circuit_117 ...
# ((not (B xor A) and (A or B)) xor ((not B) and (B or A))) and (not ((A and B) or (A xor B)) or ((A xor B) xor (not A)))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (130, 244, 211, 304, 'and'), (322, 359, 403, 419, 'and'), (0, 403, 115, 463, 'and'), (0, 115, 110, 174, 'or'), (0, 288, 110, 347, 'or'), (133, 461, 206, 520, 'or'), (229, 569, 302, 628, 'or'), (0, 201, 105, 261, 'not'), (0, 719, 105, 779, 'not'), (0, 0, 110, 59, 'xor'), (214, 151, 302, 210, 'xor'), (0, 518, 110, 577, 'xor'), (0, 633, 110, 692, 'xor'), (118, 677, 206, 736, 'xor')]
# Parsing finished in 0.29523587226867676 s
# Generating circuit_118 ...
# (((not B) xor (B or A)) or ((not A) and (A and B))) and ((not (B and A) xor (A xor B)) and ((B and A) xor (A or B)))
# Start parsing ...
# [(130, 216, 211, 276, 'and'), (0, 259, 115, 319, 'and'), (322, 338, 403, 398, 'and'), (226, 547, 307, 607, 'and'), (0, 605, 115, 665, 'and'), (0, 87, 110, 146, 'or'), (229, 130, 302, 189, 'or'), (0, 720, 110, 779, 'or'), (0, 0, 105, 60, 'not'), (0, 173, 105, 233, 'not'), (118, 44, 206, 103, 'xor'), (0, 490, 110, 549, 'xor'), (118, 663, 206, 722, 'xor'), (0, 374, 125, 434, 'notand')]
# Parsing finished in 0.49065661430358887 s
# Generating circuit_119 ...
# (not ((B xor A) or (not B)) and ((A and B) and (B or A))) xor (((B and A) and (A or B)) xor ((B or A) or (not A)))
# Start parsing ...
# [(226, 136, 307, 196, 'and'), (0, 172, 115, 232, 'and'), (130, 230, 211, 290, 'and'), (0, 403, 115, 463, 'and'), (130, 460, 211, 520, 'and'), (133, 43, 206, 102, 'or'), (0, 288, 110, 347, 'or'), (0, 518, 110, 577, 'or'), (0, 634, 110, 693, 'or'), (133, 677, 206, 736, 'or'), (0, 86, 105, 146, 'not'), (0, 719, 105, 779, 'not'), (0, 0, 110, 59, 'xor'), (310, 353, 398, 412, 'xor'), (214, 569, 302, 628, 'xor')]
# Parsing finished in 0.27466368675231934 s
# Generating circuit_120 ...
# not (((A xor B) and (B or A)) and (not (A xor B) xor (B and A))) and (((B xor A) xor (A or B)) xor ((B and A) xor (A and B)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 345, 110, 405, 'and'), (317, 403, 398, 463, 'and'), (0, 691, 110, 751, 'and'), (0, 806, 110, 866, 'and'), (0, 115, 105, 174, 'or'), (0, 576, 105, 635, 'or'), (0, 0, 105, 59, 'xor'), (0, 230, 105, 289, 'xor'), (113, 288, 201, 347, 'xor'), (0, 461, 105, 520, 'xor'), (113, 518, 201, 577, 'xor'), (209, 634, 297, 693, 'xor'), (113, 749, 201, 808, 'xor'), (212, 172, 313, 232, 'notand')]
# Parsing finished in 0.31017541885375977 s
# Generating circuit_121 ...
# (B or C) or (C xor A)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.05058717727661133 s
# Generating circuit_122 ...
# (not B) and (A xor C)
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 0, 105, 60, 'not'), (0, 87, 110, 146, 'xor')]
# Parsing finished in 0.04441070556640625 s
# Generating circuit_123 ...
# (B and A) or (C and B)
# Start parsing ...
# [(0, 0, 108, 60, 'and'), (0, 115, 108, 175, 'and'), (126, 58, 199, 117, 'or')]
# Parsing finished in 0.04269266128540039 s
# Generating circuit_124 ...
# (A or B) xor (C and B)
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'or'), (113, 58, 201, 117, 'xor')]
# Parsing finished in 0.04902529716491699 s
# Generating circuit_125 ...
# (A and C) xor (B xor C)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.053221702575683594 s
# Generating circuit_126 ...
# (A and B) xor (not C)
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 86, 105, 146, 'not'), (118, 44, 206, 103, 'xor')]
# Parsing finished in 0.04485368728637695 s
# Generating circuit_127 ...
# not (B or C) or (C and B)
# Start parsing ...
# [(0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'or'), (128, 58, 201, 117, 'or')]
# Parsing finished in 0.14535832405090332 s
# Generating circuit_128 ...
# (not A) xor (not C)
# Start parsing ...
# [(0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (118, 29, 206, 88, 'xor')]
# Parsing finished in 0.04203224182128906 s
# Generating circuit_129 ...
# not (B xor C) or (B or A)
# Start parsing ...
# [(128, 58, 201, 117, 'or'), (0, 115, 105, 174, 'or'), (0, 0, 105, 59, 'xor')]
# Parsing finished in 0.05381298065185547 s
# Generating circuit_130 ...
# (not B) or (C and A)
# Start parsing ...
# [(0, 86, 115, 146, 'and'), (133, 44, 206, 103, 'or'), (0, 0, 105, 60, 'not')]
# Parsing finished in 0.04604291915893555 s
# Generating circuit_131 ...
# (B or A) xor (A xor B)
# Start parsing ...
# [(0, 0, 105, 59, 'or'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.04999661445617676 s
# Generating circuit_132 ...
# (A and C) and (A or C)
# Start parsing ...
# [(0, 0, 110, 60, 'and'), (126, 57, 207, 117, 'and'), (0, 116, 105, 175, 'or')]
# Parsing finished in 0.04321765899658203 s
# Generating circuit_133 ...
# (not A) xor (B xor C)
# Start parsing ...
# [(0, 0, 105, 60, 'not'), (118, 44, 206, 103, 'xor'), (0, 87, 110, 146, 'xor')]
# Parsing finished in 0.056525468826293945 s
# Generating circuit_134 ...
# (B or A) and (C and A)
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (0, 0, 105, 59, 'or')]
# Parsing finished in 0.04636263847351074 s
# Generating circuit_135 ...
# not (C xor B) xor (B xor A)
# Start parsing ...
# [(0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor'), (0, 115, 105, 174, 'xor')]
# Parsing finished in 0.05414152145385742 s
# Generating circuit_136 ...
# (B xor A) xor (C and B)
# Start parsing ...
# ...
# Parsing finished in 0.48282647132873535 s
# Generating circuit_215 ...
# ((not (B and A) xor (A or B)) and (not (A xor B) xor (not C))) or (((A xor C) xor (B or C)) xor ((not B) and (C and A)))
# Start parsing ...
# [(226, 166, 307, 226, 'and'), (130, 648, 211, 708, 'and'), (0, 691, 115, 751, 'and'), (0, 116, 110, 175, 'or'), (325, 360, 398, 419, 'or'), (0, 519, 110, 578, 'or'), (0, 317, 105, 377, 'not'), (0, 605, 105, 665, 'not'), (118, 58, 206, 117, 'xor'), (0, 231, 110, 290, 'xor'), (118, 274, 206, 333, 'xor'), (0, 403, 110, 462, 'xor'), (118, 461, 206, 520, 'xor'), (214, 555, 302, 614, 'xor'), (0, 0, 125, 60, 'notand')]
# Parsing finished in 0.2902793884277344 s
# Generating circuit_216 ...
# (((A xor C) and (C or B)) or (not (B or A) or (B and C))) and (((A xor B) xor (A and C)) xor ((C or B) and (A or C)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 345, 110, 405, 'and'), (317, 403, 398, 463, 'and'), (0, 575, 111, 635, 'and'), (125, 748, 206, 808, 'and'), (0, 115, 105, 174, 'or'), (224, 173, 297, 232, 'or'), (128, 288, 201, 347, 'or'), (0, 691, 105, 750, 'or'), (0, 806, 105, 865, 'or'), (0, 0, 105, 59, 'xor'), (0, 461, 105, 520, 'xor'), (113, 518, 201, 577, 'xor'), (209, 634, 297, 693, 'xor'), (0, 230, 120, 289, 'notor')]
# Parsing finished in 0.27377939224243164 s
# Generating circuit_217 ...
# (((A or C) and (B or A)) or ((B xor C) xor (A and C))) or (((B xor A) xor (not A)) and ((A xor C) xor (C or A)))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (0, 345, 115, 405, 'and'), (226, 597, 307, 657, 'and'), (0, 0, 110, 59, 'or'), (0, 115, 110, 174, 'or'), (229, 173, 302, 232, 'or'), (325, 385, 398, 444, 'or'), (0, 749, 110, 808, 'or'), (0, 547, 105, 607, 'not'), (0, 230, 110, 289, 'xor'), (118, 288, 206, 347, 'xor'), (0, 461, 110, 520, 'xor'), (118, 504, 206, 563, 'xor'), (0, 633, 110, 692, 'xor'), (118, 691, 206, 750, 'xor')]
# Parsing finished in 0.31035757064819336 s
# Generating circuit_218 ...
# (((B or A) and (not B)) xor ((B and A) xor (A xor B))) and (not ((B xor C) xor (A xor B)) and ((A or C) or (not C)))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 172, 115, 232, 'and'), (322, 352, 403, 412, 'and'), (226, 568, 307, 628, 'and'), (0, 0, 110, 59, 'or'), (0, 634, 110, 693, 'or'), (133, 677, 206, 736, 'or'), (0, 86, 105, 146, 'not'), (0, 719, 105, 779, 'not'), (214, 137, 302, 196, 'xor'), (118, 230, 206, 289, 'xor'), (0, 288, 110, 347, 'xor'), (0, 403, 110, 462, 'xor'), (118, 461, 206, 520, 'xor'), (0, 518, 110, 577, 'xor')]
# Parsing finished in 0.4374518394470215 s
# Generating circuit_219 ...
# not (((A xor B) and (not C)) or ((B and C) and (B or A))) xor (((not B) xor (not A)) or ((A or B) xor (C and B)))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 172, 115, 232, 'and'), (130, 230, 211, 290, 'and'), (0, 633, 115, 693, 'and'), (229, 137, 302, 196, 'or'), (0, 288, 110, 347, 'or'), (229, 490, 302, 549, 'or'), (0, 518, 110, 577, 'or'), (0, 86, 105, 146, 'not'), (0, 374, 105, 434, 'not'), (0, 431, 105, 491, 'not'), (0, 0, 110, 59, 'xor'), (310, 313, 398, 372, 'xor'), (118, 403, 206, 462, 'xor'), (118, 576, 206, 635, 'xor')]
# Parsing finished in 0.22245240211486816 s
# Generating circuit_220 ...
# (not ((A xor B) or (B xor C)) and ((C xor A) or (not C))) or (((B or A) xor (C xor B)) or ((A and C) or (not A)))
# Start parsing ...
# [(226, 165, 307, 225, 'and'), (0, 633, 115, 693, 'and'), (133, 274, 206, 333, 'or'), (325, 367, 398, 426, 'or'), (0, 403, 110, 462, 'or'), (229, 569, 302, 628, 'or'), (133, 677, 206, 736, 'or'), (0, 316, 105, 376, 'not'), (0, 719, 105, 779, 'not'), (0, 0, 110, 59, 'xor'), (0, 115, 110, 174, 'xor'), (0, 230, 110, 289, 'xor'), (118, 461, 206, 520, 'xor'), (0, 518, 110, 577, 'xor')]
# Parsing finished in 0.4046049118041992 s
# Generating circuit_221 ...
# (((not C) or (not B)) or (not (A or C) xor (not C))) xor (not ((B or C) xor (B or A)) or ((not B) or (C and B)))
# Start parsing ...
# [(0, 605, 115, 665, 'and'), (133, 29, 206, 88, 'or'), (229, 108, 302, 167, 'or'), (0, 317, 110, 376, 'or'), (0, 432, 110, 491, 'or'), (229, 468, 302, 527, 'or'), (133, 562, 206, 621, 'or'), (0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (0, 230, 105, 290, 'not'), (0, 518, 105, 578, 'not'), (118, 188, 206, 247, 'xor'), (118, 375, 206, 434, 'xor'), (0, 144, 125, 203, 'notor')]
# Parsing finished in 0.2267322540283203 s
# Generating circuit_222 ...
# ((not (B xor A) and (A or B)) xor ((B or A) or (A or B))) or (((A or B) xor (A xor B)) xor ((C xor B) xor (C and A)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 806, 110, 866, 'and'), (0, 115, 105, 174, 'or'), (0, 230, 105, 289, 'or'), (128, 288, 201, 347, 'or'), (0, 346, 105, 405, 'or'), (320, 403, 393, 462, 'or'), (0, 461, 105, 520, 'or'), (0, 0, 105, 59, 'xor'), (209, 173, 297, 232, 'xor'), (113, 518, 201, 577, 'xor'), (0, 576, 105, 635, 'xor'), (209, 634, 297, 693, 'xor'), (0, 691, 105, 750, 'xor'), (113, 749, 201, 808, 'xor')]
# Parsing finished in 0.4212641716003418 s
# Generating circuit_223 ...
# (((not B) xor (A or B)) xor (not (C and B) xor (C xor A))) and (((B or A) and (B xor C)) and (not (A and C) xor (A or B)))
# Start parsing ...
# [(322, 378, 403, 438, 'and'), (130, 490, 211, 550, 'and'), (226, 605, 307, 665, 'and'), (0, 87, 110, 146, 'or'), (0, 432, 110, 491, 'or'), (0, 778, 110, 837, 'or'), (0, 0, 105, 60, 'not'), (118, 44, 206, 103, 'xor'), (214, 152, 302, 211, 'xor'), (118, 260, 206, 319, 'xor'), (0, 317, 110, 376, 'xor'), (0, 547, 110, 606, 'xor'), (0, 202, 125, 262, 'notand'), (0, 662, 125, 722, 'notand')]
# Parsing finished in 0.31801795959472656 s
# Generating circuit_224 ...
# not (((C and B) and (B or C)) and ((not A) and (A xor C))) and (((C or A) xor (B or A)) or ((C and B) or (not C)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (130, 58, 211, 118, 'and'), (130, 245, 211, 305, 'and'), (322, 360, 403, 420, 'and'), (0, 634, 115, 694, 'and'), (0, 116, 110, 175, 'or'), (0, 404, 110, 463, 'or'), (0, 519, 110, 578, 'or'), (229, 569, 302, 628, 'or'), (133, 677, 206, 736, 'or'), (0, 201, 105, 261, 'not'), (0, 720, 105, 780, 'not'), (0, 288, 110, 347, 'xor'), (118, 461, 206, 520, 'xor'), (216, 151, 317, 211, 'notand')]
# Parsing finished in 0.25670313835144043 s
# Generating circuit_225 ...
# (((B xor C) xor (B or C)) and ((C and A) or (B xor C))) or (((B and A) and (A xor B)) and ((B and A) and (A xor C)))
# Start parsing ...
# [(221, 172, 302, 232, 'and'), (0, 230, 110, 290, 'and'), (0, 460, 110, 520, 'and'), (125, 518, 206, 578, 'and'), (221, 633, 302, 693, 'and'), (0, 691, 110, 751, 'and'), (125, 748, 206, 808, 'and'), (0, 115, 105, 174, 'or'), (128, 288, 201, 347, 'or'), (320, 403, 393, 462, 'or'), (0, 0, 105, 59, 'xor'), (113, 58, 201, 117, 'xor'), (0, 345, 105, 404, 'xor'), (0, 576, 105, 635, 'xor'), (0, 806, 105, 865, 'xor')]
# Parsing finished in 0.4422628879547119 s
# Generating circuit_226 ...
# (not ((not A) or (C or A)) or ((C or B) xor (B and A))) and (not ((not C) and (C or A)) or ((not B) or (not A)))
# Start parsing ...
# [(0, 317, 115, 377, 'and'), (322, 338, 403, 398, 'and'), (133, 44, 206, 103, 'or'), (0, 87, 110, 146, 'or'), (229, 152, 302, 211, 'or'), (0, 202, 110, 261, 'or'), (0, 490, 110, 549, 'or'), (229, 526, 302, 585, 'or'), (133, 605, 206, 664, 'or'), (0, 0, 105, 60, 'not'), (0, 403, 105, 463, 'not'), (0, 576, 105, 636, 'not'), (0, 633, 105, 693, 'not'), (118, 260, 206, 319, 'xor'), (121, 446, 222, 506, 'notand')]
# Parsing finished in 0.4478180408477783 s
# Generating circuit_227 ...
# (not ((C xor B) or (B and A)) and (not (C xor B) and (B and A))) or (not ((C and A) and (B and C)) xor ((not B) xor (C and B)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (226, 172, 307, 232, 'and'), (130, 287, 211, 347, 'and'), (0, 345, 115, 405, 'and'), (0, 460, 115, 520, 'and'), (0, 575, 115, 635, 'and'), (0, 748, 115, 808, 'and'), (325, 392, 398, 451, 'or'), (0, 662, 105, 722, 'not'), (0, 0, 110, 59, 'xor'), (0, 230, 110, 289, 'xor'), (214, 612, 302, 671, 'xor'), (118, 706, 206, 765, 'xor'), (120, 518, 221, 578, 'notand')]
# Parsing finished in 0.29775500297546387 s
# Generating circuit_228 ...
# (not ((A xor B) and (C and A)) or ((A and C) and (not B))) and (((A or C) and (A or B)) and ((not A) xor (C and B)))
# Start parsing ...
# [(0, 115, 115, 175, 'and'), (0, 230, 115, 290, 'and'), (130, 273, 211, 333, 'and'), (322, 359, 403, 419, 'and'), (130, 460, 211, 520, 'and'), (226, 554, 307, 614, 'and'), (0, 691, 115, 751, 'and'), (229, 166, 302, 225, 'or'), (0, 403, 110, 462, 'or'), (0, 518, 110, 577, 'or'), (0, 316, 105, 376, 'not'), (0, 604, 105, 664, 'not'), (0, 0, 110, 59, 'xor'), (118, 648, 206, 707, 'xor'), (120, 57, 221, 117, 'notand')]
# Parsing finished in 0.24753642082214355 s
# Generating circuit_229 ...
# (((not C) or (not A)) or ((A or B) or (not B))) and (((C and B) or (C or B)) xor ((B and C) or (not C)))
# Start parsing ...
# [(322, 295, 403, 355, 'and'), (0, 317, 115, 377, 'and'), (0, 547, 115, 607, 'and'), (133, 29, 206, 88, 'or'), (229, 108, 302, 167, 'or'), (0, 144, 110, 203, 'or'), (133, 188, 206, 247, 'or'), (133, 375, 206, 434, 'or'), (0, 432, 110, 491, 'or'), (133, 591, 206, 650, 'or'), (0, 0, 105, 60, 'not'), (0, 57, 105, 117, 'not'), (0, 230, 105, 290, 'not'), (0, 633, 105, 693, 'not'), (214, 483, 302, 542, 'xor')]
# Parsing finished in 0.2199409008026123 s
# Generating circuit_230 ...
# (not ((B and C) or (B or C)) or ((C or B) xor (B xor C))) xor (((B and A) or (A and B)) xor ((A xor B) or (not A)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (0, 461, 115, 521, 'and'), (0, 576, 115, 636, 'and'), (133, 58, 206, 117, 'or'), (0, 116, 110, 175, 'or'), (229, 173, 302, 232, 'or'), (0, 231, 110, 290, 'or'), (133, 519, 206, 578, 'or'), (133, 735, 206, 794, 'or'), (0, 777, 105, 837, 'not'), (0, 346, 110, 405, 'xor'), (310, 400, 398, 459, 'xor'), (214, 627, 302, 686, 'xor'), (0, 691, 110, 750, 'xor')]
# Parsing finished in 0.2577505111694336 s
# Generating circuit_231 ...
# (((not B) and (A and C)) xor ((B xor A) and (not B))) xor (((A or B) and (not B)) or ((not A) xor (B xor C)))
# Start parsing ...
# [(130, 43, 211, 103, 'and'), (0, 86, 115, 146, 'and'), (130, 245, 211, 305, 'and'), (130, 418, 211, 478, 'and'), (0, 375, 110, 434, 'or'), (229, 490, 302, 549, 'or'), (0, 0, 105, 60, 'not'), (0, 288, 105, 348, 'not'), (0, 461, 105, 521, 'not'), (0, 518, 105, 578, 'not'), (0, 202, 110, 261, 'xor'), (310, 317, 398, 376, 'xor'), (118, 562, 206, 621, 'xor'), (0, 605, 110, 664, 'xor')]
# Parsing finished in 0.3295414447784424 s
# Generating circuit_232 ...
# (((C or A) and (C or B)) and (not (B xor A) and (B and A))) and (((A or C) or (B and C)) or ((not B) and (A or C)))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (226, 172, 307, 232, 'and'), (130, 287, 211, 347, 'and'), (0, 345, 115, 405, 'and'), (322, 392, 403, 452, 'and'), (0, 575, 115, 635, 'and'), (130, 705, 211, 765, 'and'), (0, 0, 110, 59, 'or'), (0, 115, 110, 174, 'or'), (0, 461, 110, 520, 'or'), (133, 518, 206, 577, 'or'), (229, 612, 302, 671, 'or'), (0, 749, 110, 808, 'or'), (0, 662, 105, 722, 'not'), (0, 230, 110, 289, 'xor')]
# Parsing finished in 0.24400639533996582 s
# Generating circuit_233 ...
# (not ((A xor C) and (not C)) or ((B xor A) or (not B))) and (not ((C and A) or (C or B)) and ((A xor C) xor (B and C)))
# Start parsing ...
# [(322, 323, 403, 383, 'and'), (0, 345, 115, 405, 'and'), (226, 518, 307, 578, 'and'), (0, 691, 115, 751, 'and'), (229, 130, 302, 189, 'or'), (133, 216, 206, 275, 'or'), (133, 403, 206, 462, 'or'), (0, 461, 110, 520, 'or'), (0, 86, 105, 146, 'not'), (0, 259, 105, 319, 'not'), (0, 0, 110, 59, 'xor'), (0, 173, 110, 232, 'xor'), (0, 576, 110, 635, 'xor'), (118, 634, 206, 693, 'xor'), (121, 43, 222, 103, 'notand')]
# Parsing finished in 0.2635376453399658 s
# Generating circuit_234 ...
# (((B and A) or (not B)) and ((not A) xor (C and A))) xor ((not (B or C) xor (A and C)) or ((B xor C) xor (B xor A)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (226, 115, 307, 175, 'and'), (0, 230, 115, 290, 'and'), (0, 461, 115, 521, 'and'), (133, 44, 206, 103, 'or'), (0, 346, 110, 405, 'or'), (229, 519, 302, 578, 'or'), (0, 86, 105, 146, 'not'), (0, 144, 105, 204, 'not'), (118, 188, 206, 247, 'xor'), (310, 317, 398, 376, 'xor'), (118, 404, 206, 463, 'xor'), (0, 576, 110, 635, 'xor'), (118, 634, 206, 693, 'xor'), (0, 691, 110, 750, 'xor')]
# Parsing finished in 0.2803809642791748 s
# Generating circuit_235 ...
# (not ((A and B) and (not A)) xor ((C xor B) xor (C xor A))) and ((not (C and B) xor (not A)) and ((not C) and (B or C)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (322, 328, 403, 388, 'and'), (226, 518, 307, 578, 'and'), (130, 590, 211, 650, 'and'), (0, 634, 110, 693, 'or'), (0, 86, 105, 146, 'not'), (0, 489, 105, 549, 'not'), (0, 547, 105, 607, 'not'), (214, 137, 302, 196, 'xor'), (0, 173, 110, 232, 'xor'), (118, 231, 206, 290, 'xor'), (0, 288, 110, 347, 'xor'), (118, 447, 206, 506, 'xor'), (120, 43, 221, 103, 'notand'), (0, 403, 125, 463, 'notand')]
# Parsing finished in 0.37301063537597656 s
# Generating circuit_236 ...
# (not ((B xor A) and (C and B)) xor ((C or A) xor (B or C))) or (not ((B or C) and (B or A)) and ((B xor A) xor (A and C)))
# Start parsing ...
# [(126, 57, 207, 117, 'and'), (0, 115, 110, 175, 'and'), (126, 518, 207, 578, 'and'), (221, 633, 302, 693, 'and'), (0, 806, 110, 866, 'and'), (0, 230, 105, 289, 'or'), (0, 346, 105, 405, 'or'), (320, 403, 393, 462, 'or'), (0, 461, 105, 520, 'or'), (0, 576, 105, 635, 'or'), (0, 0, 105, 59, 'xor'), (209, 173, 297, 232, 'xor'), (113, 288, 201, 347, 'xor'), (0, 691, 105, 750, 'xor'), (113, 749, 201, 808, 'xor')]
# Parsing finished in 0.315565824508667 s
# Generating circuit_237 ...
# ((not (A and B) or (not C)) or ((C or A) and (B xor A))) xor ((not (C xor A) xor (B and A)) xor ((not B) and (B xor A)))
# Start parsing ...
# [(130, 230, 211, 290, 'and'), (0, 518, 115, 578, 'and'), (130, 648, 211, 708, 'and'), (133, 44, 206, 103, 'or'), (229, 137, 302, 196, 'or'), (0, 173, 110, 232, 'or'), (0, 86, 105, 146, 'not'), (0, 605, 105, 665, 'not'), (0, 288, 110, 347, 'xor'), (310, 346, 398, 405, 'xor'), (0, 404, 110, 463, 'xor'), (118, 461, 206, 520, 'xor'), (214, 555, 302, 614, 'xor'), (0, 691, 110, 750, 'xor'), (0, 0, 125, 60, 'notand')]
# Parsing finished in 0.27324438095092773 s
# Generating circuit_238 ...
# ((not (B or A) and (A and B)) and (not (A and C) or (C xor B))) or (((B xor A) or (A xor C)) and (not (C or A) or (B and C)))
# Start parsing ...
# [(125, 57, 206, 117, 'and'), (0, 115, 110, 175, 'and'), (221, 172, 302, 232, 'and'), (0, 230, 111, 290, 'and'), (221, 633, 302, 693, 'and'), (0, 806, 110, 866, 'and'), (0, 0, 105, 59, 'or'), (128, 288, 201, 347, 'or'), (320, 403, 393, 462, 'or'), (128, 518, 201, 577, 'or'), (0, 691, 105, 750, 'or'), (128, 749, 201, 808, 'or'), (0, 345, 105, 404, 'xor'), (0, 461, 105, 520, 'xor'), (0, 576, 105, 635, 'xor')]
# Parsing finished in 0.30277109146118164 s
# Generating circuit_239 ...
# not (((A and C) xor (not A)) xor ((not C) and (not A))) and (((not A) and (not C)) or ((A or C) xor (B xor C)))
# Start parsing ...
# [(0, 0, 115, 60, 'and'), (130, 173, 211, 233, 'and'), (322, 241, 403, 301, 'and'), (130, 288, 211, 348, 'and'), (229, 375, 302, 434, 'or'), (0, 404, 110, 463, 'or'), (0, 86, 105, 146, 'not'), (0, 144, 105, 204, 'not'), (0, 201, 105, 261, 'not'), (0, 259, 105, 319, 'not'), (0, 317, 105, 377, 'not'), (118, 44, 206, 103, 'xor'), (118, 461, 206, 520, 'xor'), (0, 519, 110, 578, 'xor')]
# Parsing finished in 0.34393906593322754 s
# Generating circuit_240 ...
# ((not (B or C) and (C xor B)) xor ((not A) and (not B))) or (not ((not C) xor (C and B)) xor ((not B) or (B xor C)))
# Start parsing ...
# [(130, 57, 211, 117, 'and'), (130, 230, 211, 290, 'and'), (0, 403, 115, 463, 'and'), (0, 0, 110, 59, 'or'), (325, 295, 398, 354, 'or'), (133, 533, 206, 592, 'or'), (0, 201, 105, 261, 'not'), (0, 259, 105, 319, 'not'), (0, 316, 105, 376, 'not'), (0, 489, 105, 549, 'not'), (0, 115, 110, 174, 'xor'), (214, 144, 302, 203, 'xor'), (118, 360, 206, 419, 'xor'), (214, 446, 302, 505, 'xor'), (0, 576, 110, 635, 'xor')]
# Parsing finished in 0.27282094955444336 s

# %%
import cv2
import numpy as np
from PIL import Image


def draw_bbox(img_path, output_path):
    # Load the image (grayscale from alpha channel)
    img = np.array(Image.open(img_path))[:, :, 3]

    # Load templates for all 7 gates
    template_and = np.array(Image.open('./and.png'))[:, :, 3]
    template_or = np.array(Image.open('./or.png'))[:, :, 3]
    template_not = np.array(Image.open('./not.png'))[:, :, 3]
    template_xor = np.array(Image.open('./xor.png'))[:, :, 3]
    template_notand = np.array(Image.open('./notand.png'))[:, :, 3]
    template_notor = np.array(Image.open('./notor.png'))[:, :, 3]
    template_notxor = np.array(Image.open('./notxor.png'))[:, :, 3]

    # Perform template matching for each gate
    result_and = cv2.matchTemplate(img, template_and, cv2.TM_CCOEFF_NORMED)
    result_or = cv2.matchTemplate(img, template_or, cv2.TM_CCOEFF_NORMED)
    result_not = cv2.matchTemplate(img, template_not, cv2.TM_CCOEFF_NORMED)
    result_xor = cv2.matchTemplate(img, template_xor, cv2.TM_CCOEFF_NORMED)
    result_notand = cv2.matchTemplate(img, template_notand, cv2.TM_CCOEFF_NORMED)
    result_notor = cv2.matchTemplate(img, template_notor, cv2.TM_CCOEFF_NORMED)
    result_notxor = cv2.matchTemplate(img, template_notxor, cv2.TM_CCOEFF_NORMED)

    # Define thresholds for each gate
    threshold_and = 0.94
    threshold_or = 0.94
    threshold_not = 0.94
    threshold_xor = 0.87
    threshold_notand = 0.87
    threshold_notor = 0.87
    threshold_notxor = 0.87

    # Find locations for matches above the thresholds
    loc_and = np.where(result_and >= threshold_and)
    loc_or = np.where(result_or >= threshold_or)
    loc_not = np.where(result_not >= threshold_not)
    loc_xor = np.where(result_xor >= threshold_xor)
    loc_notand = np.where(result_notand >= threshold_notand)
    loc_notor = np.where(result_notor >= threshold_notor)
    loc_notxor = np.where(result_notxor >= threshold_notxor)

    # Convert the image to 3-channel RGB to draw colored rectangles
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

    # Define colors for each gate
    color_and = (255, 0, 0)      # Blue for AND
    color_or = (0, 255, 0)       # Green for OR
    color_not = (0, 0, 255)      # Red for NOT
    color_xor = (255, 255, 0)    # Cyan for XOR
    color_notand = (255, 0, 255) # Magenta for NOTAND
    color_notor = (0, 255, 255)  # Yellow for NOTOR
    color_notxor = (128, 128, 128) # Gray for NOTXOR

    # Draw rectangles for each gate
    for pt in zip(*loc_and[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_and.shape[1], pt[1] + template_and.shape[0]), color_and, 2)
        print("识别到与门 (AND)")

    for pt in zip(*loc_or[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_or.shape[1], pt[1] + template_or.shape[0]), color_or, 2)
        print("识别到或门 (OR)")

    for pt in zip(*loc_not[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_not.shape[1], pt[1] + template_not.shape[0]), color_not, 2)
        print("识别到非门 (NOT)")

    for pt in zip(*loc_xor[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_xor.shape[1], pt[1] + template_xor.shape[0]), color_xor, 2)
        print("识别到异或门 (XOR)")

    for pt in zip(*loc_notand[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_notand.shape[1], pt[1] + template_notand.shape[0]), color_notand, 2)
        print("识别到与非门 (NOTAND)")

    for pt in zip(*loc_notor[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_notor.shape[1], pt[1] + template_notor.shape[0]), color_notor, 2)
        print("识别到或非门 (NOTOR)")

    for pt in zip(*loc_notxor[::-1]):
        cv2.rectangle(img, pt, (pt[0] + template_notxor.shape[1], pt[1] + template_notxor.shape[0]), color_notxor, 2)
        print("识别到异或非门 (NOTXOR)")

    # Save the resulting image with detected gates
    cv2.imwrite(output_path, img)

    # # Display the resulting image
    # cv2.imshow('Detected Circuit Components', img)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

# %%
for i in range(21, 25):
    draw_bbox(f"./circuits_output2/circuit_{i}.png", f"./circuits_output2_bbox/circuit_{i}.png")
# Out:
# 识别到与门 (AND)
# 识别到或门 (OR)
# 识别到或门 (OR)
# 识别到异或门 (XOR)
# 识别到异或门 (XOR)
# 识别到与非门 (NOTAND)
# 识别到异或门 (XOR)
# 识别到异或门 (XOR)
# 识别到异或门 (XOR)
# 识别到与非门 (NOTAND)
# 识别到与门 (AND)
# 识别到与门 (AND)
# 识别到非门 (NOT)
# 识别到与非门 (NOTAND)
# 识别到与非门 (NOTAND)
# 识别到与门 (AND)
# 识别到或门 (OR)
# 识别到或门 (OR)
# 识别到异或门 (XOR)
# 识别到异或门 (XOR)
# 识别到与非门 (NOTAND)
